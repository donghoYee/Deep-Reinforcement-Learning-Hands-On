# %% [markdown]
# # Playing MissPackman with DQN

# %% [markdown]
# * playing with ehe environment to see what is needed

# %%
import pyvirtualdisplay, os
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %%
env_name = "MsPacman-v4"

# %%
import cv2 
import gym
import gym.spaces
import numpy as np
import collections
import torch
import torch.nn as nn
import torch.optim as optim
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt

# %%
env = gym.make(env_name)

# %%
print(env.observation_space.shape)
# Out:
# (210, 160, 3)

# %%
print(env.action_space.n)
# Out:
# 9

# %%
print(env.unwrapped.get_action_meanings())
# Out:
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']

# %%
from IPython.display import clear_output
import time
state = env.reset()
plt.imshow(state)
plt.show()
for i in range(88):
    time.sleep(0.01)
    char = '3'#input()
    if char == 'q':
        break
    clear_output()
    state, reward, done, info = env.step(int(char))
    print(reward)
    plt.imshow(state)
    plt.show()
# Out:
# 0.0

# %%
plt.imshow(state)
plt.show()
while(True):
    time.sleep(0.1)
    char = "1"
    if char == 'q':
        break
    clear_output()
    state, reward, done, info = env.step(int(char))
    print(reward)
    plt.imshow(state)
    plt.show()
    break #
# Out:
# 0.0

# %% [markdown]
# * first needs 88 steps of nothing ness!

# %% [markdown]
# #### Create wrappers accordingly!

# %%
START_FRAME_COUNT = 88

class RestartEnv(gym.Wrapper): # press fire at the beginning of episode
    def __init__(self, env=None): 
        super(RestartEnv, self).__init__(env) # pass self.env env
        pass
    
    def step(self, action):
        obs, reward, is_done, info = self.env.step(action) # just pass
        if(info['ale.lives'] == 2):
            is_done = True
        return obs, reward, is_done, info
        
    def reset(self): # on reset
        self.env.reset()
        for _ in range(START_FRAME_COUNT):
            obs, _, done, _ = self.env.step(0)
        if done:
            self.env.reset()
        return obs

# %%
class MaxAndSkipEnv(gym.Wrapper): # skips frames and obs is max to prevent flickering
    def __init__(self, env = None, skip=4):
        # return only every "skip"-th frame
        super(MaxAndSkipEnv, self).__init__(env)
        self._obs_buffer = collections.deque(maxlen=2) # most recent observations
        self._skip = skip
        pass
    
    def step(self, action):
        total_reward = 0.0
        done = None
        for _ in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break
                
        max_frame = np.max(np.stack(self._obs_buffer), axis=0)
        return max_frame, total_reward, done, info
    
    def reset(self): # clear buffer and init
        self._obs_buffer.clear()
        obs = self.env.reset()
        self._obs_buffer.append(obs) # save the first obs!
        return obs

# %%
class ProcessFrame84(gym.ObservationWrapper): # resize and grayscale image
    def __init__(self, env = None):
        super(ProcessFrame84, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(128, 128, 1), dtype=np.uint8)
        pass
    
    def observation(self, obs):
        return ProcessFrame84.process(obs) # do not use self.process?
    
    @staticmethod
    def process(frame):
        if frame.size == 210*160*3:
            img = np.reshape(frame, [210, 160, 3]).astype(np.float32)
        elif frame.size == 250*160*3:
            img = np.reshape(frame, [250, 160, 3]).astype(np.float32)
        else:
            assert False, "Unknown resolution."
        img = img[:, :, 0] * 0.299 + img[:, :, 1]*0.587 + img[:, :, 2]*0.114 # grayscale formula
        resized_screen = cv2.resize(img, (128, 156), interpolation=cv2.INTER_AREA)
        x_t = resized_screen[:128, :] # crop height
        x_t = np.reshape(x_t, [128, 128, 1])
        return x_t.astype(np.uint8)

# %%
class BufferWrapper(gym.ObservationWrapper): # give buffered past observations as output
    def __init__(self, env, n_steps, dtype=np.float32): # buffer for n_steps
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(
            old_space.low.repeat(n_steps, axis=0),
            old_space.high.repeat(n_steps, axis=0), dtype=dtype)
        pass
    
    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low, dtype=self.dtype) # fill the buffer
        return self.observation(self.env.reset())
    
    def observation(self, observation):
        self.buffer[:-1] = self.buffer[1:] # just like a deque buffer
        self.buffer[:-1] = observation
        return self.buffer

# %%
class ImageToPytorch(gym.ObservationWrapper): # HWC to CHW required by pytorch
    def __init__(self, env):
        super(ImageToPytorch, self).__init__(env)
        old_shape = self.observation_space.shape
        new_shape = (old_shape[-1], old_shape[0], old_shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=new_shape, dtype=np.float32)
        pass
    
    def observation(self, observation):
        return np.moveaxis(observation, 2,0)

# %%
class ScaledFloatFrame(gym.ObservationWrapper): # buffer to float , 0~1
    def observation(self, observation):
        return np.array(observation).astype(np.float32) / 255.0

# %%
class RewardWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)
    
    def reward(self, reward):
        # modify rew
        return reward / 100.0 # reward is big on this

# %%
def wrap_env(env):
    env = RestartEnv(env)
    env = MaxAndSkipEnv(env)
    env = ProcessFrame84(env)
    env = ImageToPytorch(env)
    env = BufferWrapper(env, n_steps=4)
    env = ScaledFloatFrame(env)
    env = RewardWrapper(env)
    return env

# %%
env = gym.make(env_name)
env = wrap_env(env)

# %%
state = env.reset()
print(state.shape)
# Out:
# (4, 128, 128)

# %%
plt.imshow(state[0])

# %%
state, reward, done, info = env.step(1)

plt.imshow(state[0])

# %%
print(info['ale.lives'])
# Out:
# 3

# %%
print(done)
# Out:
# False

# %% [markdown]
# ### The DQN model

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions): # input shape doesn't regard batch size!
        super(DQN, self).__init__()
        
        self.conv = nn.Sequential(
            # input channel_n, output_channel_n, filter size, stride
            nn.Conv2d(input_shape[0], 32, kernel_size = 8, stride = 4), 
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        conv_out_size = self._get_conv_out(input_shape)
        print("conv out size: ",conv_out_size)
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512), # input size, output size
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)# get Q(s,a)
        )
        
    def _get_conv_out(self, shape): # get output shape of conv net
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size())) # get the total number of pixels
    
    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1) # what does this do? -> flatten!
        return self.fc(conv_out)

# %% [markdown]
# ### Training

# %%
MEAN_REWARD_BOUND = 50

GAMMA = 0.99 # gamma value
BATCH_SIZE = 256
REPLAY_SIZE = 100000
LEARNING_RATE = 1e-3
SYNC_TARGET_FRAMES = 1000 # sync between target
REPLAY_START_SIZE = 100000

EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_START = 1.0
EPSILON_FINAL = 0.005

# %%
Experience = collections.namedtuple("Experience", field_names=["state", "action", "reward","done", "new_state"])

class ExperienceBuffer: # return better ones to see
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size,
                                   replace=False)
        states, actions, rewards, dones, next_states = \
            zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), \
               np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), \
               np.array(next_states)

# %%
class Agent:
    def __init__(self, env, exp_buffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self._reset()

    def _reset(self):
        self.state = env.reset()
        self.total_reward = 0.0

    @torch.no_grad()
    def play_step(self, net, epsilon=0.0, device="cpu"):
        done_reward = None

        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_a = np.array([self.state], copy=False)
            state_v = torch.tensor(state_a).to(device)
            q_vals_v = net(state_v)
            _, act_v = torch.max(q_vals_v, dim=1)
            action = int(act_v.item())

        # do step in the environment
        new_state, reward, is_done, _ = self.env.step(action)
        self.total_reward += reward

        exp = Experience(self.state, action, reward,
                         is_done, new_state)
        self.exp_buffer.append(exp)
        self.state = new_state
        if is_done:
            done_reward = self.total_reward
            self._reset()
            
        return done_reward

# %%
def calc_loss(batch, net, tgt_net, device="cpu"): # to train net
    states, actions, rewards, dones, next_states = batch

    states_v = torch.tensor(np.array(
        states, copy=False)).to(device)
    next_states_v = torch.tensor(np.array(
        next_states, copy=False)).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.BoolTensor(dones).to(device)

    state_action_values = net(states_v).gather(
        1, actions_v.unsqueeze(-1)).squeeze(-1)
    with torch.no_grad():
        next_state_values = tgt_net(next_states_v).max(1)[0]
        next_state_values[done_mask] = 0.0
        next_state_values = next_state_values.detach()

    expected_state_action_values = next_state_values * GAMMA + \
                                   rewards_v
    return nn.MSELoss()(state_action_values,
                        expected_state_action_values)

# %%
# main
device = torch.device("cuda") ###### cuda!!

net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device)

writer = SummaryWriter(comment="-"+env_name)
print(net)
# Out:
# conv out size:  6400
# conv out size:  6400
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=6400, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=9, bias=True)
#   )
# )

# %%
buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
epsilon = EPSILON_START

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
LEARNING_RATE_END = 1e-5

total_rewards = []
frame_idx = 0
ts_frame = 0
ts = time.time()
best_m_reward = None

while True:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START*(1-(frame_idx-REPLAY_START_SIZE) / EPSILON_DECAY_LAST_FRAME)) # use max!!
    optimizer.lr = max(LEARNING_RATE_END, LEARNING_RATE*(1-(frame_idx-REPLAY_START_SIZE) / EPSILON_DECAY_LAST_FRAME))
    
    reward = agent.play_step(net, epsilon, device=device)
    if reward is not None: # episode is over
        total_rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts) # frames per sec
        ts_frame = frame_idx
        ts = time.time()
        m_reward = np.mean(total_rewards[-100:])
        print("%d: done %d games, lr %.5f reward %.3f, "
              "eps %.2f, speed %.2f f/s" % (
                  frame_idx, len(total_rewards),optimizer.lr, m_reward, epsilon, speed))
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("speed", speed, frame_idx)
        writer.add_scalar("reward_100", m_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)
        writer.add_scalar("learning_rate", optimizer.lr, frame_idx)
        if best_m_reward is None or best_m_reward < m_reward:
            torch.save(net.state_dict(), env_name+"-best_%.0f.dat" % m_reward)
            if best_m_reward is not None:
                print("Best reward updated %.3f -> %.3f" %(best_m_reward, m_reward))
            best_m_reward = m_reward
            
        if m_reward > MEAN_REWARD_BOUND:
            print("Solved in %d frames!: " % frame_idx)
            break
            
    if len(buffer) < REPLAY_START_SIZE: # not enough buffer
        continue
        
    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict()) # sync two nets
    
    optimizer.zero_grad()
    batch = buffer.sample(BATCH_SIZE) # train with every new steps
    loss_t = calc_loss(batch, net, tgt_net, device=device)
    loss_t.backward()
    optimizer.step()
    
writer.close()
# Out:
# 43: done 1 games, lr 0.00167 reward 1.900, eps 1.67, speed 365.05 f/s
# 81: done 2 games, lr 0.00167 reward 1.550, eps 1.67, speed 242.53 f/s
# 121: done 3 games, lr 0.00167 reward 1.733, eps 1.67, speed 361.80 f/s
# 228: done 4 games, lr 0.00167 reward 2.575, eps 1.67, speed 436.73 f/s
# Best reward updated 1.900 -> 2.575
# 257: done 5 games, lr 0.00166 reward 2.380, eps 1.66, speed 203.68 f/s
# 311: done 6 games, lr 0.00166 reward 2.383, eps 1.66, speed 389.71 f/s
# 349: done 7 games, lr 0.00166 reward 2.243, eps 1.66, speed 310.28 f/s
# 397: done 8 games, lr 0.00166 reward 2.138, eps 1.66, speed 381.45 f/s
# 439: done 9 games, lr 0.00166 reward 2.144, eps 1.66, speed 357.38 f/s
# 479: done 10 games, lr 0.00166 reward 2.090, eps 1.66, speed 340.81 f/s
# 504: done 11 games, lr 0.00166 reward 1.991, eps 1.66, speed 291.20 f/s
# 617: done 12 games, lr 0.00166 reward 2.242, eps 1.66, speed 445.37 f/s
# 650: done 13 games, lr 0.00166 reward 2.154, eps 1.66, speed 326.32 f/s
# 700: done 14 games, lr 0.00166 reward 2.157, eps 1.66, speed 330.03 f/s
# 730: done 15 games, lr 0.00166 reward 2.087, eps 1.66, speed 319.63 f/s
# 775: done 16 games, lr 0.00166 reward 2.056, eps 1.66, speed 369.83 f/s
# 824: done 17 games, lr 0.00166 reward 2.071, eps 1.66, speed 378.01 f/s
# 860: done 18 games, lr 0.00166 reward 2.017, eps 1.66, speed 343.91 f/s
# 892: done 19 games, lr 0.00166 reward 1.953, eps 1.66, speed 320.31 f/s
# 940: done 20 games, lr 0.00166 reward 1.940, eps 1.66, speed 377.55 f/s
# 976: done 21 games, lr 0.00166 reward 1.919, eps 1.66, speed 329.69 f/s
# 1017: done 22 games, lr 0.00166 reward 1.882, eps 1.66, speed 349.04 f/s
# 1055: done 23 games, lr 0.00166 reward 1.883, eps 1.66, speed 347.23 f/s
# 1099: done 24 games, lr 0.00166 reward 1.867, eps 1.66, speed 361.29 f/s
# 1132: done 25 games, lr 0.00166 reward 1.836, eps 1.66, speed 339.49 f/s
# 1184: done 26 games, lr 0.00166 reward 1.835, eps 1.66, speed 372.10 f/s
# 1236: done 27 games, lr 0.00166 reward 1.870, eps 1.66, speed 386.66 f/s
# 1269: done 28 games, lr 0.00166 reward 1.836, eps 1.66, speed 336.85 f/s
# 1307: done 29 games, lr 0.00166 reward 1.810, eps 1.66, speed 347.36 f/s
# 1385: done 30 games, lr 0.00166 reward 1.957, eps 1.66, speed 417.60 f/s
# 1419: done 31 games, lr 0.00166 reward 1.942, eps 1.66, speed 338.71 f/s
# 1453: done 32 games, lr 0.00166 reward 1.922, eps 1.66, speed 342.67 f/s
# 1485: done 33 games, lr 0.00166 reward 1.897, eps 1.66, speed 324.31 f/s
# 1502: done 34 games, lr 0.00166 reward 1.862, eps 1.66, speed 251.77 f/s
# 1531: done 35 games, lr 0.00166 reward 1.837, eps 1.66, speed 319.40 f/s
# 1577: done 36 games, lr 0.00166 reward 1.822, eps 1.66, speed 366.78 f/s
# 1615: done 37 games, lr 0.00166 reward 1.805, eps 1.66, speed 341.53 f/s
# 1645: done 38 games, lr 0.00166 reward 1.787, eps 1.66, speed 314.38 f/s
# 1677: done 39 games, lr 0.00166 reward 1.779, eps 1.66, speed 320.49 f/s
# 1714: done 40 games, lr 0.00166 reward 1.752, eps 1.66, speed 339.25 f/s
# 1732: done 41 games, lr 0.00166 reward 1.722, eps 1.66, speed 254.49 f/s
# 1818: done 42 games, lr 0.00165 reward 1.788, eps 1.65, speed 420.04 f/s
# 1839: done 43 games, lr 0.00165 reward 1.770, eps 1.65, speed 270.43 f/s
# 1876: done 44 games, lr 0.00165 reward 1.755, eps 1.65, speed 341.83 f/s
# 1897: done 45 games, lr 0.00165 reward 1.733, eps 1.65, speed 277.77 f/s
# 1934: done 46 games, lr 0.00165 reward 1.730, eps 1.65, speed 350.22 f/s
# 1975: done 47 games, lr 0.00165 reward 1.738, eps 1.65, speed 354.85 f/s
# 2097: done 48 games, lr 0.00165 reward 1.919, eps 1.65, speed 440.73 f/s
# 2143: done 49 games, lr 0.00165 reward 1.916, eps 1.65, speed 364.20 f/s
# 2181: done 50 games, lr 0.00165 reward 1.902, eps 1.65, speed 350.56 f/s
# 2223: done 51 games, lr 0.00165 reward 1.886, eps 1.65, speed 367.22 f/s
# 2265: done 52 games, lr 0.00165 reward 1.888, eps 1.65, speed 353.52 f/s
# 2298: done 53 games, lr 0.00165 reward 1.877, eps 1.65, speed 331.84 f/s
# 2316: done 54 games, lr 0.00165 reward 1.852, eps 1.65, speed 253.56 f/s
# 2361: done 55 games, lr 0.00165 reward 1.844, eps 1.65, speed 369.49 f/s
# 2412: done 56 games, lr 0.00165 reward 1.845, eps 1.65, speed 384.68 f/s
# 2442: done 57 games, lr 0.00165 reward 1.830, eps 1.65, speed 319.86 f/s
# 2492: done 58 games, lr 0.00165 reward 1.829, eps 1.65, speed 367.41 f/s
# 2531: done 59 games, lr 0.00165 reward 1.819, eps 1.65, speed 351.17 f/s
# 2570: done 60 games, lr 0.00165 reward 1.813, eps 1.65, speed 353.60 f/s
# 2608: done 61 games, lr 0.00165 reward 1.800, eps 1.65, speed 354.23 f/s
# 2649: done 62 games, lr 0.00165 reward 1.792, eps 1.65, speed 357.14 f/s
# 2685: done 63 games, lr 0.00165 reward 1.792, eps 1.65, speed 334.56 f/s
# 2822: done 64 games, lr 0.00165 reward 1.864, eps 1.65, speed 448.08 f/s
# 2903: done 65 games, lr 0.00165 reward 1.912, eps 1.65, speed 412.45 f/s
# 3052: done 66 games, lr 0.00165 reward 2.017, eps 1.65, speed 459.37 f/s
# 3099: done 67 games, lr 0.00165 reward 2.006, eps 1.65, speed 377.27 f/s
# 3143: done 68 games, lr 0.00165 reward 1.996, eps 1.65, speed 360.96 f/s
# 3185: done 69 games, lr 0.00165 reward 1.994, eps 1.65, speed 357.43 f/s
# 3224: done 70 games, lr 0.00165 reward 1.979, eps 1.65, speed 355.99 f/s
# 3362: done 71 games, lr 0.00164 reward 1.997, eps 1.64, speed 460.96 f/s
# 3380: done 72 games, lr 0.00164 reward 1.978, eps 1.64, speed 261.38 f/s
# 3396: done 73 games, lr 0.00164 reward 1.959, eps 1.64, speed 240.71 f/s
# 3443: done 74 games, lr 0.00164 reward 1.954, eps 1.64, speed 376.04 f/s
# 3537: done 75 games, lr 0.00164 reward 1.963, eps 1.64, speed 429.43 f/s
# 3582: done 76 games, lr 0.00164 reward 1.963, eps 1.64, speed 360.60 f/s
# 3629: done 77 games, lr 0.00164 reward 1.961, eps 1.64, speed 366.35 f/s
# 3667: done 78 games, lr 0.00164 reward 1.954, eps 1.64, speed 348.05 f/s
# 3706: done 79 games, lr 0.00164 reward 1.951, eps 1.64, speed 350.79 f/s
# 3804: done 80 games, lr 0.00164 reward 1.994, eps 1.64, speed 426.74 f/s
# 3845: done 81 games, lr 0.00164 reward 1.988, eps 1.64, speed 362.38 f/s
# 3879: done 82 games, lr 0.00164 reward 1.977, eps 1.64, speed 339.31 f/s
# 3906: done 83 games, lr 0.00164 reward 1.961, eps 1.64, speed 306.13 f/s
# 3954: done 84 games, lr 0.00164 reward 1.958, eps 1.64, speed 370.38 f/s
# 3990: done 85 games, lr 0.00164 reward 1.947, eps 1.64, speed 331.29 f/s
# 4066: done 86 games, lr 0.00164 reward 1.997, eps 1.64, speed 414.78 f/s
# 4171: done 87 games, lr 0.00164 reward 2.039, eps 1.64, speed 446.03 f/s
# 4215: done 88 games, lr 0.00164 reward 2.036, eps 1.64, speed 356.71 f/s
# 4256: done 89 games, lr 0.00164 reward 2.030, eps 1.64, speed 358.66 f/s
# 4349: done 90 games, lr 0.00164 reward 2.077, eps 1.64, speed 435.84 f/s
# 4399: done 91 games, lr 0.00164 reward 2.074, eps 1.64, speed 373.38 f/s
# 4435: done 92 games, lr 0.00164 reward 2.065, eps 1.64, speed 330.72 f/s
# 4487: done 93 games, lr 0.00164 reward 2.061, eps 1.64, speed 378.61 f/s
# 4518: done 94 games, lr 0.00164 reward 2.051, eps 1.64, speed 325.23 f/s
# 4557: done 95 games, lr 0.00164 reward 2.044, eps 1.64, speed 354.36 f/s
# 4585: done 96 games, lr 0.00164 reward 2.033, eps 1.64, speed 319.31 f/s
# 4679: done 97 games, lr 0.00164 reward 2.052, eps 1.64, speed 421.10 f/s
# 4721: done 98 games, lr 0.00164 reward 2.046, eps 1.64, speed 364.93 f/s
# 4736: done 99 games, lr 0.00164 reward 2.030, eps 1.64, speed 231.35 f/s
# 4777: done 100 games, lr 0.00163 reward 2.022, eps 1.63, speed 359.56 f/s
# 4817: done 101 games, lr 0.00163 reward 2.017, eps 1.63, speed 351.85 f/s
# 4849: done 102 games, lr 0.00163 reward 2.018, eps 1.63, speed 324.55 f/s
# 4867: done 103 games, lr 0.00163 reward 2.003, eps 1.63, speed 263.17 f/s
# 4904: done 104 games, lr 0.00163 reward 1.961, eps 1.63, speed 357.08 f/s
# 4945: done 105 games, lr 0.00163 reward 1.958, eps 1.63, speed 362.55 f/s
# 4988: done 106 games, lr 0.00163 reward 1.952, eps 1.63, speed 361.31 f/s
# 5004: done 107 games, lr 0.00163 reward 1.943, eps 1.63, speed 242.09 f/s
# 5041: done 108 games, lr 0.00163 reward 1.944, eps 1.63, speed 340.05 f/s
# 5063: done 109 games, lr 0.00163 reward 1.933, eps 1.63, speed 283.25 f/s
# 5109: done 110 games, lr 0.00163 reward 1.935, eps 1.63, speed 370.74 f/s
# 5149: done 111 games, lr 0.00163 reward 1.937, eps 1.63, speed 351.83 f/s
# 5193: done 112 games, lr 0.00163 reward 1.904, eps 1.63, speed 363.45 f/s
# 5235: done 113 games, lr 0.00163 reward 1.907, eps 1.63, speed 354.81 f/s
# 5273: done 114 games, lr 0.00163 reward 1.906, eps 1.63, speed 352.43 f/s
# 5307: done 115 games, lr 0.00163 reward 1.905, eps 1.63, speed 335.94 f/s
# 5346: done 116 games, lr 0.00163 reward 1.901, eps 1.63, speed 354.22 f/s
# 5384: done 117 games, lr 0.00163 reward 1.896, eps 1.63, speed 345.27 f/s
# 5428: done 118 games, lr 0.00163 reward 1.902, eps 1.63, speed 354.79 f/s
# 5465: done 119 games, lr 0.00163 reward 1.908, eps 1.63, speed 346.05 f/s
# 5500: done 120 games, lr 0.00163 reward 1.901, eps 1.63, speed 340.56 f/s
# 5546: done 121 games, lr 0.00163 reward 1.903, eps 1.63, speed 370.31 f/s
# 5585: done 122 games, lr 0.00163 reward 1.903, eps 1.63, speed 348.96 f/s
# 5616: done 123 games, lr 0.00163 reward 1.892, eps 1.63, speed 326.64 f/s
# 5655: done 124 games, lr 0.00163 reward 1.891, eps 1.63, speed 348.17 f/s
# 5695: done 125 games, lr 0.00163 reward 1.891, eps 1.63, speed 353.55 f/s
# 5743: done 126 games, lr 0.00163 reward 1.890, eps 1.63, speed 374.59 f/s
# 5829: done 127 games, lr 0.00163 reward 1.902, eps 1.63, speed 421.31 f/s
# 5921: done 128 games, lr 0.00163 reward 1.987, eps 1.63, speed 430.25 f/s
# 5967: done 129 games, lr 0.00163 reward 1.992, eps 1.63, speed 370.54 f/s
# 6008: done 130 games, lr 0.00163 reward 1.943, eps 1.63, speed 356.65 f/s
# 6038: done 131 games, lr 0.00163 reward 1.940, eps 1.63, speed 318.91 f/s
# 6086: done 132 games, lr 0.00163 reward 1.940, eps 1.63, speed 374.02 f/s
# 6105: done 133 games, lr 0.00163 reward 1.935, eps 1.63, speed 173.50 f/s
# 6146: done 134 games, lr 0.00163 reward 1.945, eps 1.63, speed 364.87 f/s
# 6188: done 135 games, lr 0.00163 reward 1.944, eps 1.63, speed 354.92 f/s
# 6207: done 136 games, lr 0.00163 reward 1.939, eps 1.63, speed 265.69 f/s
# 6229: done 137 games, lr 0.00163 reward 1.938, eps 1.63, speed 273.77 f/s
# 6273: done 138 games, lr 0.00162 reward 1.942, eps 1.62, speed 367.32 f/s
# 6312: done 139 games, lr 0.00162 reward 1.938, eps 1.62, speed 355.14 f/s
# 6352: done 140 games, lr 0.00162 reward 1.945, eps 1.62, speed 364.42 f/s
# 6396: done 141 games, lr 0.00162 reward 1.953, eps 1.62, speed 358.30 f/s
# 6439: done 142 games, lr 0.00162 reward 1.924, eps 1.62, speed 353.92 f/s
# 6480: done 143 games, lr 0.00162 reward 1.936, eps 1.62, speed 356.84 f/s
# 6515: done 144 games, lr 0.00162 reward 1.939, eps 1.62, speed 298.96 f/s
# 6545: done 145 games, lr 0.00162 reward 1.944, eps 1.62, speed 318.33 f/s
# 6597: done 146 games, lr 0.00162 reward 1.947, eps 1.62, speed 379.97 f/s
# 6641: done 147 games, lr 0.00162 reward 1.939, eps 1.62, speed 361.41 f/s
# 6679: done 148 games, lr 0.00162 reward 1.849, eps 1.62, speed 355.65 f/s
# 6699: done 149 games, lr 0.00162 reward 1.838, eps 1.62, speed 274.41 f/s
# 6738: done 150 games, lr 0.00162 reward 1.845, eps 1.62, speed 343.56 f/s
# 6777: done 151 games, lr 0.00162 reward 1.847, eps 1.62, speed 346.92 f/s
# 6834: done 152 games, lr 0.00162 reward 1.851, eps 1.62, speed 390.95 f/s
# 6873: done 153 games, lr 0.00162 reward 1.853, eps 1.62, speed 354.39 f/s
# 6906: done 154 games, lr 0.00162 reward 1.863, eps 1.62, speed 339.95 f/s
# 6940: done 155 games, lr 0.00162 reward 1.862, eps 1.62, speed 338.30 f/s
# 6955: done 156 games, lr 0.00162 reward 1.850, eps 1.62, speed 237.01 f/s
# 6998: done 157 games, lr 0.00162 reward 1.855, eps 1.62, speed 353.75 f/s
# 7038: done 158 games, lr 0.00162 reward 1.857, eps 1.62, speed 353.94 f/s
# 7077: done 159 games, lr 0.00162 reward 1.857, eps 1.62, speed 353.93 f/s
# 7120: done 160 games, lr 0.00162 reward 1.856, eps 1.62, speed 361.93 f/s
# 7161: done 161 games, lr 0.00162 reward 1.861, eps 1.62, speed 348.46 f/s
# 7193: done 162 games, lr 0.00162 reward 1.860, eps 1.62, speed 316.50 f/s
# 7240: done 163 games, lr 0.00162 reward 1.859, eps 1.62, speed 365.39 f/s
# 7300: done 164 games, lr 0.00162 reward 1.821, eps 1.62, speed 397.17 f/s
# 7342: done 165 games, lr 0.00162 reward 1.786, eps 1.62, speed 361.05 f/s
# 7383: done 166 games, lr 0.00162 reward 1.716, eps 1.62, speed 360.58 f/s
# 7432: done 167 games, lr 0.00162 reward 1.732, eps 1.62, speed 369.73 f/s
# 7483: done 168 games, lr 0.00162 reward 1.745, eps 1.62, speed 377.44 f/s
# 7522: done 169 games, lr 0.00162 reward 1.744, eps 1.62, speed 350.30 f/s
# 7569: done 170 games, lr 0.00162 reward 1.757, eps 1.62, speed 367.58 f/s
# 7617: done 171 games, lr 0.00162 reward 1.738, eps 1.62, speed 370.77 f/s
# 7635: done 172 games, lr 0.00162 reward 1.739, eps 1.62, speed 254.54 f/s
# 7657: done 173 games, lr 0.00162 reward 1.739, eps 1.62, speed 284.81 f/s
# 7696: done 174 games, lr 0.00162 reward 1.730, eps 1.62, speed 353.63 f/s
# 7787: done 175 games, lr 0.00161 reward 1.760, eps 1.61, speed 425.00 f/s
# 7827: done 176 games, lr 0.00161 reward 1.758, eps 1.61, speed 352.09 f/s
# 7874: done 177 games, lr 0.00161 reward 1.762, eps 1.61, speed 367.61 f/s
# 7917: done 178 games, lr 0.00161 reward 1.762, eps 1.61, speed 368.33 f/s
# 7962: done 179 games, lr 0.00161 reward 1.761, eps 1.61, speed 375.59 f/s
# 8005: done 180 games, lr 0.00161 reward 1.722, eps 1.61, speed 361.17 f/s
# 8086: done 181 games, lr 0.00161 reward 1.745, eps 1.61, speed 420.10 f/s
# 8133: done 182 games, lr 0.00161 reward 1.751, eps 1.61, speed 372.94 f/s
# 8241: done 183 games, lr 0.00161 reward 1.778, eps 1.61, speed 443.21 f/s
# 8294: done 184 games, lr 0.00161 reward 1.783, eps 1.61, speed 381.60 f/s
# 8338: done 185 games, lr 0.00161 reward 1.787, eps 1.61, speed 366.00 f/s
# 8374: done 186 games, lr 0.00161 reward 1.741, eps 1.61, speed 350.73 f/s
# 8419: done 187 games, lr 0.00161 reward 1.698, eps 1.61, speed 365.09 f/s
# 8475: done 188 games, lr 0.00161 reward 1.698, eps 1.61, speed 381.87 f/s
# 8509: done 189 games, lr 0.00161 reward 1.697, eps 1.61, speed 333.82 f/s
# 8531: done 190 games, lr 0.00161 reward 1.642, eps 1.61, speed 276.75 f/s
# 8573: done 191 games, lr 0.00161 reward 1.635, eps 1.61, speed 347.72 f/s
# 8627: done 192 games, lr 0.00161 reward 1.643, eps 1.61, speed 380.14 f/s
# 8668: done 193 games, lr 0.00161 reward 1.639, eps 1.61, speed 350.24 f/s
# 8710: done 194 games, lr 0.00161 reward 1.639, eps 1.61, speed 355.48 f/s
# 8749: done 195 games, lr 0.00161 reward 1.641, eps 1.61, speed 352.94 f/s
# 8789: done 196 games, lr 0.00161 reward 1.637, eps 1.61, speed 352.54 f/s
# 8814: done 197 games, lr 0.00161 reward 1.609, eps 1.61, speed 306.57 f/s
# 8853: done 198 games, lr 0.00161 reward 1.614, eps 1.61, speed 338.43 f/s
# 8908: done 199 games, lr 0.00161 reward 1.628, eps 1.61, speed 383.89 f/s
# 8938: done 200 games, lr 0.00161 reward 1.631, eps 1.61, speed 312.10 f/s
# 8959: done 201 games, lr 0.00161 reward 1.625, eps 1.61, speed 271.42 f/s
# 8980: done 202 games, lr 0.00161 reward 1.618, eps 1.61, speed 275.81 f/s
# 9034: done 203 games, lr 0.00161 reward 1.637, eps 1.61, speed 383.34 f/s
# 9076: done 204 games, lr 0.00161 reward 1.646, eps 1.61, speed 351.75 f/s
# 9113: done 205 games, lr 0.00161 reward 1.646, eps 1.61, speed 343.43 f/s
# 9146: done 206 games, lr 0.00161 reward 1.640, eps 1.61, speed 338.72 f/s
# 9189: done 207 games, lr 0.00161 reward 1.652, eps 1.61, speed 364.17 f/s
# 9222: done 208 games, lr 0.00161 reward 1.647, eps 1.61, speed 340.66 f/s
# 9251: done 209 games, lr 0.00160 reward 1.646, eps 1.60, speed 315.94 f/s
# 9295: done 210 games, lr 0.00160 reward 1.643, eps 1.60, speed 365.11 f/s
# 9330: done 211 games, lr 0.00160 reward 1.640, eps 1.60, speed 342.00 f/s
# 9376: done 212 games, lr 0.00160 reward 1.643, eps 1.60, speed 367.41 f/s
# 9426: done 213 games, lr 0.00160 reward 1.640, eps 1.60, speed 378.61 f/s
# 9459: done 214 games, lr 0.00160 reward 1.635, eps 1.60, speed 325.80 f/s
# 9496: done 215 games, lr 0.00160 reward 1.642, eps 1.60, speed 342.72 f/s
# 9536: done 216 games, lr 0.00160 reward 1.643, eps 1.60, speed 359.16 f/s
# 9559: done 217 games, lr 0.00160 reward 1.630, eps 1.60, speed 295.10 f/s
# 9582: done 218 games, lr 0.00160 reward 1.621, eps 1.60, speed 284.86 f/s
# 9608: done 219 games, lr 0.00160 reward 1.615, eps 1.60, speed 305.33 f/s
# 9648: done 220 games, lr 0.00160 reward 1.614, eps 1.60, speed 357.50 f/s
# 9684: done 221 games, lr 0.00160 reward 1.615, eps 1.60, speed 341.12 f/s
# 9724: done 222 games, lr 0.00160 reward 1.617, eps 1.60, speed 355.80 f/s
# 9760: done 223 games, lr 0.00160 reward 1.621, eps 1.60, speed 344.77 f/s
# 9799: done 224 games, lr 0.00160 reward 1.627, eps 1.60, speed 354.39 f/s
# 9846: done 225 games, lr 0.00160 reward 1.632, eps 1.60, speed 373.83 f/s
# 9869: done 226 games, lr 0.00160 reward 1.624, eps 1.60, speed 285.20 f/s
# 9885: done 227 games, lr 0.00160 reward 1.591, eps 1.60, speed 239.09 f/s
# 9910: done 228 games, lr 0.00160 reward 1.510, eps 1.60, speed 297.93 f/s
# 9955: done 229 games, lr 0.00160 reward 1.514, eps 1.60, speed 371.95 f/s
# 9982: done 230 games, lr 0.00160 reward 1.514, eps 1.60, speed 305.26 f/s
# 10041: done 231 games, lr 0.00160 reward 1.523, eps 1.60, speed 393.55 f/s
# 10078: done 232 games, lr 0.00160 reward 1.524, eps 1.60, speed 336.60 f/s
# 10156: done 233 games, lr 0.00160 reward 1.565, eps 1.60, speed 418.84 f/s
# 10205: done 234 games, lr 0.00160 reward 1.565, eps 1.60, speed 380.68 f/s
# 10249: done 235 games, lr 0.00160 reward 1.569, eps 1.60, speed 360.80 f/s
# 10288: done 236 games, lr 0.00160 reward 1.571, eps 1.60, speed 349.06 f/s
# 10331: done 237 games, lr 0.00160 reward 1.573, eps 1.60, speed 373.82 f/s
# 10369: done 238 games, lr 0.00160 reward 1.570, eps 1.60, speed 349.23 f/s
# 10407: done 239 games, lr 0.00160 reward 1.571, eps 1.60, speed 354.62 f/s
# 10471: done 240 games, lr 0.00160 reward 1.575, eps 1.60, speed 398.95 f/s
# 10516: done 241 games, lr 0.00160 reward 1.574, eps 1.60, speed 369.30 f/s
# 10559: done 242 games, lr 0.00160 reward 1.580, eps 1.60, speed 371.34 f/s
# 10582: done 243 games, lr 0.00160 reward 1.565, eps 1.60, speed 285.45 f/s
# 10620: done 244 games, lr 0.00160 reward 1.566, eps 1.60, speed 352.91 f/s
# 10639: done 245 games, lr 0.00160 reward 1.558, eps 1.60, speed 255.26 f/s
# 10674: done 246 games, lr 0.00160 reward 1.552, eps 1.60, speed 331.82 f/s
# 10725: done 247 games, lr 0.00160 reward 1.559, eps 1.60, speed 380.14 f/s
# 10774: done 248 games, lr 0.00159 reward 1.561, eps 1.59, speed 382.58 f/s
# 10811: done 249 games, lr 0.00159 reward 1.565, eps 1.59, speed 344.82 f/s
# 10848: done 250 games, lr 0.00159 reward 1.553, eps 1.59, speed 347.22 f/s
# 10875: done 251 games, lr 0.00159 reward 1.554, eps 1.59, speed 299.77 f/s
# 10891: done 252 games, lr 0.00159 reward 1.536, eps 1.59, speed 238.72 f/s
# 10933: done 253 games, lr 0.00159 reward 1.544, eps 1.59, speed 361.05 f/s
# 10970: done 254 games, lr 0.00159 reward 1.542, eps 1.59, speed 349.83 f/s
# 10988: done 255 games, lr 0.00159 reward 1.536, eps 1.59, speed 257.32 f/s
# 11026: done 256 games, lr 0.00159 reward 1.539, eps 1.59, speed 346.19 f/s
# 11071: done 257 games, lr 0.00159 reward 1.535, eps 1.59, speed 354.11 f/s
# 11108: done 258 games, lr 0.00159 reward 1.525, eps 1.59, speed 346.68 f/s
# 11149: done 259 games, lr 0.00159 reward 1.528, eps 1.59, speed 351.02 f/s
# 11194: done 260 games, lr 0.00159 reward 1.529, eps 1.59, speed 369.01 f/s
# 11238: done 261 games, lr 0.00159 reward 1.531, eps 1.59, speed 359.13 f/s
# 11274: done 262 games, lr 0.00159 reward 1.531, eps 1.59, speed 343.37 f/s
# 11323: done 263 games, lr 0.00159 reward 1.535, eps 1.59, speed 384.53 f/s
# 11377: done 264 games, lr 0.00159 reward 1.534, eps 1.59, speed 391.43 f/s
# 11417: done 265 games, lr 0.00159 reward 1.534, eps 1.59, speed 355.23 f/s
# 11460: done 266 games, lr 0.00159 reward 1.524, eps 1.59, speed 349.42 f/s
# 11507: done 267 games, lr 0.00159 reward 1.515, eps 1.59, speed 368.89 f/s
# 11545: done 268 games, lr 0.00159 reward 1.502, eps 1.59, speed 352.01 f/s
# 11597: done 269 games, lr 0.00159 reward 1.506, eps 1.59, speed 383.25 f/s
# 11629: done 270 games, lr 0.00159 reward 1.496, eps 1.59, speed 328.49 f/s
# 11674: done 271 games, lr 0.00159 reward 1.503, eps 1.59, speed 363.86 f/s
# 11723: done 272 games, lr 0.00159 reward 1.512, eps 1.59, speed 373.15 f/s
# 11755: done 273 games, lr 0.00159 reward 1.515, eps 1.59, speed 329.48 f/s
# 11777: done 274 games, lr 0.00159 reward 1.515, eps 1.59, speed 285.84 f/s
# 11812: done 275 games, lr 0.00159 reward 1.476, eps 1.59, speed 333.87 f/s
# 11861: done 276 games, lr 0.00159 reward 1.481, eps 1.59, speed 372.15 f/s
# 11897: done 277 games, lr 0.00159 reward 1.476, eps 1.59, speed 345.92 f/s
# 11947: done 278 games, lr 0.00159 reward 1.476, eps 1.59, speed 388.64 f/s
# 11990: done 279 games, lr 0.00159 reward 1.473, eps 1.59, speed 361.55 f/s
# 12045: done 280 games, lr 0.00159 reward 1.476, eps 1.59, speed 383.57 f/s
# 12087: done 281 games, lr 0.00159 reward 1.454, eps 1.59, speed 348.89 f/s
# 12123: done 282 games, lr 0.00159 reward 1.446, eps 1.59, speed 342.65 f/s
# 12148: done 283 games, lr 0.00159 reward 1.425, eps 1.59, speed 305.94 f/s
# 12180: done 284 games, lr 0.00159 reward 1.412, eps 1.59, speed 329.60 f/s
# 12227: done 285 games, lr 0.00159 reward 1.415, eps 1.59, speed 366.60 f/s
# 12266: done 286 games, lr 0.00158 reward 1.410, eps 1.58, speed 357.03 f/s
# 12313: done 287 games, lr 0.00158 reward 1.422, eps 1.58, speed 366.05 f/s
# 12336: done 288 games, lr 0.00158 reward 1.411, eps 1.58, speed 291.34 f/s
# 12384: done 289 games, lr 0.00158 reward 1.414, eps 1.58, speed 372.18 f/s
# 12427: done 290 games, lr 0.00158 reward 1.423, eps 1.58, speed 365.32 f/s
# 12465: done 291 games, lr 0.00158 reward 1.424, eps 1.58, speed 339.57 f/s
# 12530: done 292 games, lr 0.00158 reward 1.422, eps 1.58, speed 406.34 f/s
# 12578: done 293 games, lr 0.00158 reward 1.420, eps 1.58, speed 367.39 f/s
# 12608: done 294 games, lr 0.00158 reward 1.419, eps 1.58, speed 322.92 f/s
# 12645: done 295 games, lr 0.00158 reward 1.414, eps 1.58, speed 346.18 f/s
# 12686: done 296 games, lr 0.00158 reward 1.420, eps 1.58, speed 355.25 f/s
# 12729: done 297 games, lr 0.00158 reward 1.426, eps 1.58, speed 367.35 f/s
# 12777: done 298 games, lr 0.00158 reward 1.429, eps 1.58, speed 375.90 f/s
# 12816: done 299 games, lr 0.00158 reward 1.423, eps 1.58, speed 352.71 f/s
# 12860: done 300 games, lr 0.00158 reward 1.427, eps 1.58, speed 363.83 f/s
# 12909: done 301 games, lr 0.00158 reward 1.437, eps 1.58, speed 372.83 f/s
# 12955: done 302 games, lr 0.00158 reward 1.447, eps 1.58, speed 362.72 f/s
# 12981: done 303 games, lr 0.00158 reward 1.431, eps 1.58, speed 293.59 f/s
# 13028: done 304 games, lr 0.00158 reward 1.432, eps 1.58, speed 381.23 f/s
# 13069: done 305 games, lr 0.00158 reward 1.438, eps 1.58, speed 353.45 f/s
# 13115: done 306 games, lr 0.00158 reward 1.442, eps 1.58, speed 366.81 f/s
# 13159: done 307 games, lr 0.00158 reward 1.439, eps 1.58, speed 374.86 f/s
# 13204: done 308 games, lr 0.00158 reward 1.447, eps 1.58, speed 369.28 f/s
# 13383: done 309 games, lr 0.00158 reward 1.557, eps 1.58, speed 460.74 f/s
# 13429: done 310 games, lr 0.00158 reward 1.562, eps 1.58, speed 374.53 f/s
# 13455: done 311 games, lr 0.00158 reward 1.561, eps 1.58, speed 307.66 f/s
# 13492: done 312 games, lr 0.00158 reward 1.552, eps 1.58, speed 346.06 f/s
# 13536: done 313 games, lr 0.00158 reward 1.553, eps 1.58, speed 356.82 f/s
# 13631: done 314 games, lr 0.00158 reward 1.564, eps 1.58, speed 430.32 f/s
# 13670: done 315 games, lr 0.00158 reward 1.561, eps 1.58, speed 354.09 f/s
# 13711: done 316 games, lr 0.00158 reward 1.559, eps 1.58, speed 357.99 f/s
# 13735: done 317 games, lr 0.00158 reward 1.562, eps 1.58, speed 290.93 f/s
# 13777: done 318 games, lr 0.00157 reward 1.569, eps 1.57, speed 357.75 f/s
# 13817: done 319 games, lr 0.00157 reward 1.580, eps 1.57, speed 356.37 f/s
# 13851: done 320 games, lr 0.00157 reward 1.582, eps 1.57, speed 339.63 f/s
# 13897: done 321 games, lr 0.00157 reward 1.577, eps 1.57, speed 369.93 f/s
# 13942: done 322 games, lr 0.00157 reward 1.575, eps 1.57, speed 362.45 f/s
# 13966: done 323 games, lr 0.00157 reward 1.573, eps 1.57, speed 283.92 f/s
# 14007: done 324 games, lr 0.00157 reward 1.576, eps 1.57, speed 351.16 f/s
# 14045: done 325 games, lr 0.00157 reward 1.569, eps 1.57, speed 349.18 f/s
# 14091: done 326 games, lr 0.00157 reward 1.579, eps 1.57, speed 374.38 f/s
# 14137: done 327 games, lr 0.00157 reward 1.592, eps 1.57, speed 377.23 f/s
# 14156: done 328 games, lr 0.00157 reward 1.584, eps 1.57, speed 265.01 f/s
# 14215: done 329 games, lr 0.00157 reward 1.585, eps 1.57, speed 391.25 f/s
# 14262: done 330 games, lr 0.00157 reward 1.589, eps 1.57, speed 370.57 f/s
# 14305: done 331 games, lr 0.00157 reward 1.582, eps 1.57, speed 362.80 f/s
# 14405: done 332 games, lr 0.00157 reward 1.597, eps 1.57, speed 426.11 f/s
# 14425: done 333 games, lr 0.00157 reward 1.562, eps 1.57, speed 272.67 f/s
# 14447: done 334 games, lr 0.00157 reward 1.552, eps 1.57, speed 287.63 f/s
# 14494: done 335 games, lr 0.00157 reward 1.550, eps 1.57, speed 382.82 f/s
# 14540: done 336 games, lr 0.00157 reward 1.559, eps 1.57, speed 367.15 f/s
# 14641: done 337 games, lr 0.00157 reward 1.647, eps 1.57, speed 429.48 f/s
# 14676: done 338 games, lr 0.00157 reward 1.646, eps 1.57, speed 344.88 f/s
# 14714: done 339 games, lr 0.00157 reward 1.643, eps 1.57, speed 352.59 f/s
# 14749: done 340 games, lr 0.00157 reward 1.636, eps 1.57, speed 348.95 f/s
# 14783: done 341 games, lr 0.00157 reward 1.638, eps 1.57, speed 325.52 f/s
# 14823: done 342 games, lr 0.00157 reward 1.632, eps 1.57, speed 350.49 f/s
# 14839: done 343 games, lr 0.00157 reward 1.631, eps 1.57, speed 244.31 f/s
# 14877: done 344 games, lr 0.00157 reward 1.635, eps 1.57, speed 350.07 f/s
# 14923: done 345 games, lr 0.00157 reward 1.646, eps 1.57, speed 380.54 f/s
# 14973: done 346 games, lr 0.00157 reward 1.656, eps 1.57, speed 366.90 f/s
# 14995: done 347 games, lr 0.00157 reward 1.647, eps 1.57, speed 274.77 f/s
# 15037: done 348 games, lr 0.00157 reward 1.646, eps 1.57, speed 363.60 f/s
# 15059: done 349 games, lr 0.00157 reward 1.640, eps 1.57, speed 277.80 f/s
# 15103: done 350 games, lr 0.00157 reward 1.648, eps 1.57, speed 368.75 f/s
# 15139: done 351 games, lr 0.00157 reward 1.646, eps 1.57, speed 332.25 f/s
# 15191: done 352 games, lr 0.00157 reward 1.655, eps 1.57, speed 375.56 f/s
# 15227: done 353 games, lr 0.00157 reward 1.649, eps 1.57, speed 340.57 f/s
# 15261: done 354 games, lr 0.00156 reward 1.645, eps 1.56, speed 347.78 f/s
# 15297: done 355 games, lr 0.00156 reward 1.648, eps 1.56, speed 345.75 f/s
# 15339: done 356 games, lr 0.00156 reward 1.650, eps 1.56, speed 350.48 f/s
# 15357: done 357 games, lr 0.00156 reward 1.645, eps 1.56, speed 243.51 f/s
# 15394: done 358 games, lr 0.00156 reward 1.645, eps 1.56, speed 292.97 f/s
# 15444: done 359 games, lr 0.00156 reward 1.649, eps 1.56, speed 365.05 f/s
# 15482: done 360 games, lr 0.00156 reward 1.646, eps 1.56, speed 343.70 f/s
# 15516: done 361 games, lr 0.00156 reward 1.645, eps 1.56, speed 321.56 f/s
# 15560: done 362 games, lr 0.00156 reward 1.654, eps 1.56, speed 347.37 f/s
# 15600: done 363 games, lr 0.00156 reward 1.646, eps 1.56, speed 347.29 f/s
# 15643: done 364 games, lr 0.00156 reward 1.634, eps 1.56, speed 327.41 f/s
# 15681: done 365 games, lr 0.00156 reward 1.634, eps 1.56, speed 338.19 f/s
# 15720: done 366 games, lr 0.00156 reward 1.641, eps 1.56, speed 335.28 f/s
# 15770: done 367 games, lr 0.00156 reward 1.639, eps 1.56, speed 371.59 f/s
# 15807: done 368 games, lr 0.00156 reward 1.636, eps 1.56, speed 340.69 f/s
# 15845: done 369 games, lr 0.00156 reward 1.630, eps 1.56, speed 347.72 f/s
# 15892: done 370 games, lr 0.00156 reward 1.636, eps 1.56, speed 370.98 f/s
# 15934: done 371 games, lr 0.00156 reward 1.633, eps 1.56, speed 348.00 f/s
# 15976: done 372 games, lr 0.00156 reward 1.634, eps 1.56, speed 350.42 f/s
# 16012: done 373 games, lr 0.00156 reward 1.641, eps 1.56, speed 333.04 f/s
# 16038: done 374 games, lr 0.00156 reward 1.645, eps 1.56, speed 307.50 f/s
# 16076: done 375 games, lr 0.00156 reward 1.638, eps 1.56, speed 350.53 f/s
# 16128: done 376 games, lr 0.00156 reward 1.635, eps 1.56, speed 384.61 f/s
# 16168: done 377 games, lr 0.00156 reward 1.637, eps 1.56, speed 353.85 f/s
# 16209: done 378 games, lr 0.00156 reward 1.635, eps 1.56, speed 368.26 f/s
# 16262: done 379 games, lr 0.00156 reward 1.638, eps 1.56, speed 387.48 f/s
# 16301: done 380 games, lr 0.00156 reward 1.635, eps 1.56, speed 354.47 f/s
# 16357: done 381 games, lr 0.00156 reward 1.636, eps 1.56, speed 388.13 f/s
# 16400: done 382 games, lr 0.00156 reward 1.641, eps 1.56, speed 357.10 f/s
# 16444: done 383 games, lr 0.00156 reward 1.639, eps 1.56, speed 362.97 f/s
# 16499: done 384 games, lr 0.00156 reward 1.653, eps 1.56, speed 395.28 f/s
# 16548: done 385 games, lr 0.00156 reward 1.650, eps 1.56, speed 366.38 f/s
# 16599: done 386 games, lr 0.00156 reward 1.664, eps 1.56, speed 368.16 f/s
# 16641: done 387 games, lr 0.00156 reward 1.656, eps 1.56, speed 355.73 f/s
# 16678: done 388 games, lr 0.00156 reward 1.662, eps 1.56, speed 343.66 f/s
# 16712: done 389 games, lr 0.00156 reward 1.658, eps 1.56, speed 335.93 f/s
# 16757: done 390 games, lr 0.00155 reward 1.665, eps 1.55, speed 360.49 f/s
# 16804: done 391 games, lr 0.00155 reward 1.668, eps 1.55, speed 369.42 f/s
# 16834: done 392 games, lr 0.00155 reward 1.660, eps 1.55, speed 330.79 f/s
# 16878: done 393 games, lr 0.00155 reward 1.664, eps 1.55, speed 365.22 f/s
# 16925: done 394 games, lr 0.00155 reward 1.671, eps 1.55, speed 371.37 f/s
# 16964: done 395 games, lr 0.00155 reward 1.672, eps 1.55, speed 346.13 f/s
# 16987: done 396 games, lr 0.00155 reward 1.669, eps 1.55, speed 283.67 f/s
# 17015: done 397 games, lr 0.00155 reward 1.664, eps 1.55, speed 311.56 f/s
# 17053: done 398 games, lr 0.00155 reward 1.649, eps 1.55, speed 351.06 f/s
# 17105: done 399 games, lr 0.00155 reward 1.654, eps 1.55, speed 382.18 f/s
# 17135: done 400 games, lr 0.00155 reward 1.652, eps 1.55, speed 314.74 f/s
# 17181: done 401 games, lr 0.00155 reward 1.655, eps 1.55, speed 363.47 f/s
# 17223: done 402 games, lr 0.00155 reward 1.651, eps 1.55, speed 360.47 f/s
# 17252: done 403 games, lr 0.00155 reward 1.657, eps 1.55, speed 322.33 f/s
# 17281: done 404 games, lr 0.00155 reward 1.651, eps 1.55, speed 323.43 f/s
# 17319: done 405 games, lr 0.00155 reward 1.646, eps 1.55, speed 346.86 f/s
# 17371: done 406 games, lr 0.00155 reward 1.653, eps 1.55, speed 374.46 f/s
# 17400: done 407 games, lr 0.00155 reward 1.654, eps 1.55, speed 317.59 f/s
# 17430: done 408 games, lr 0.00155 reward 1.647, eps 1.55, speed 317.27 f/s
# 17470: done 409 games, lr 0.00155 reward 1.537, eps 1.55, speed 339.22 f/s
# 17506: done 410 games, lr 0.00155 reward 1.532, eps 1.55, speed 272.24 f/s
# 17546: done 411 games, lr 0.00155 reward 1.539, eps 1.55, speed 332.49 f/s
# 17601: done 412 games, lr 0.00155 reward 1.544, eps 1.55, speed 323.82 f/s
# 17637: done 413 games, lr 0.00155 reward 1.548, eps 1.55, speed 326.29 f/s
# 17689: done 414 games, lr 0.00155 reward 1.543, eps 1.55, speed 373.18 f/s
# 17729: done 415 games, lr 0.00155 reward 1.544, eps 1.55, speed 345.33 f/s
# 17767: done 416 games, lr 0.00155 reward 1.549, eps 1.55, speed 339.23 f/s
# 17812: done 417 games, lr 0.00155 reward 1.559, eps 1.55, speed 358.49 f/s
# 17860: done 418 games, lr 0.00155 reward 1.561, eps 1.55, speed 352.45 f/s
# 17899: done 419 games, lr 0.00155 reward 1.556, eps 1.55, speed 335.22 f/s
# 17952: done 420 games, lr 0.00155 reward 1.562, eps 1.55, speed 372.78 f/s
# 18001: done 421 games, lr 0.00155 reward 1.567, eps 1.55, speed 368.57 f/s
# 18047: done 422 games, lr 0.00155 reward 1.575, eps 1.55, speed 360.53 f/s
# 18095: done 423 games, lr 0.00155 reward 1.587, eps 1.55, speed 353.10 f/s
# 18181: done 424 games, lr 0.00155 reward 1.627, eps 1.55, speed 424.62 f/s
# 18223: done 425 games, lr 0.00155 reward 1.631, eps 1.55, speed 366.22 f/s
# 18310: done 426 games, lr 0.00154 reward 1.646, eps 1.54, speed 433.69 f/s
# 18360: done 427 games, lr 0.00154 reward 1.644, eps 1.54, speed 374.92 f/s
# 18400: done 428 games, lr 0.00154 reward 1.653, eps 1.54, speed 345.57 f/s
# 18437: done 429 games, lr 0.00154 reward 1.646, eps 1.54, speed 347.36 f/s
# 18472: done 430 games, lr 0.00154 reward 1.640, eps 1.54, speed 340.97 f/s
# 18508: done 431 games, lr 0.00154 reward 1.637, eps 1.54, speed 346.24 f/s
# 18547: done 432 games, lr 0.00154 reward 1.622, eps 1.54, speed 342.40 f/s
# 18585: done 433 games, lr 0.00154 reward 1.625, eps 1.54, speed 343.85 f/s
# 18635: done 434 games, lr 0.00154 reward 1.639, eps 1.54, speed 383.08 f/s
# 18680: done 435 games, lr 0.00154 reward 1.649, eps 1.54, speed 363.57 f/s
# 18705: done 436 games, lr 0.00154 reward 1.638, eps 1.54, speed 300.76 f/s
# 18745: done 437 games, lr 0.00154 reward 1.547, eps 1.54, speed 362.88 f/s
# 18785: done 438 games, lr 0.00154 reward 1.551, eps 1.54, speed 350.89 f/s
# 18829: done 439 games, lr 0.00154 reward 1.555, eps 1.54, speed 361.41 f/s
# 18865: done 440 games, lr 0.00154 reward 1.555, eps 1.54, speed 340.53 f/s
# 18890: done 441 games, lr 0.00154 reward 1.550, eps 1.54, speed 306.49 f/s
# 18922: done 442 games, lr 0.00154 reward 1.546, eps 1.54, speed 320.97 f/s
# 18955: done 443 games, lr 0.00154 reward 1.547, eps 1.54, speed 325.41 f/s
# 18994: done 444 games, lr 0.00154 reward 1.548, eps 1.54, speed 335.33 f/s
# 19110: done 445 games, lr 0.00154 reward 1.632, eps 1.54, speed 445.60 f/s
# 19145: done 446 games, lr 0.00154 reward 1.622, eps 1.54, speed 346.14 f/s
# 19263: done 447 games, lr 0.00154 reward 1.641, eps 1.54, speed 448.89 f/s
# 19295: done 448 games, lr 0.00154 reward 1.639, eps 1.54, speed 321.89 f/s
# 19330: done 449 games, lr 0.00154 reward 1.643, eps 1.54, speed 332.31 f/s
# 19383: done 450 games, lr 0.00154 reward 1.650, eps 1.54, speed 393.00 f/s
# 19426: done 451 games, lr 0.00154 reward 1.650, eps 1.54, speed 358.37 f/s
# 19470: done 452 games, lr 0.00154 reward 1.651, eps 1.54, speed 366.23 f/s
# 19511: done 453 games, lr 0.00154 reward 1.651, eps 1.54, speed 350.93 f/s
# 19552: done 454 games, lr 0.00154 reward 1.649, eps 1.54, speed 358.32 f/s
# 19571: done 455 games, lr 0.00154 reward 1.645, eps 1.54, speed 267.29 f/s
# 19608: done 456 games, lr 0.00154 reward 1.644, eps 1.54, speed 338.75 f/s
# 19646: done 457 games, lr 0.00154 reward 1.652, eps 1.54, speed 337.22 f/s
# 19691: done 458 games, lr 0.00154 reward 1.659, eps 1.54, speed 370.73 f/s
# 19729: done 459 games, lr 0.00154 reward 1.651, eps 1.54, speed 353.94 f/s
# 19770: done 460 games, lr 0.00153 reward 1.649, eps 1.53, speed 364.32 f/s
# 19813: done 461 games, lr 0.00153 reward 1.644, eps 1.53, speed 347.16 f/s
# 19864: done 462 games, lr 0.00153 reward 1.640, eps 1.53, speed 380.44 f/s
# 19902: done 463 games, lr 0.00153 reward 1.640, eps 1.53, speed 358.09 f/s
# 19946: done 464 games, lr 0.00153 reward 1.642, eps 1.53, speed 372.27 f/s
# 19996: done 465 games, lr 0.00153 reward 1.643, eps 1.53, speed 382.50 f/s
# 20029: done 466 games, lr 0.00153 reward 1.639, eps 1.53, speed 328.19 f/s
# 20108: done 467 games, lr 0.00153 reward 1.656, eps 1.53, speed 421.78 f/s
# 20146: done 468 games, lr 0.00153 reward 1.658, eps 1.53, speed 353.01 f/s
# 20192: done 469 games, lr 0.00153 reward 1.659, eps 1.53, speed 367.62 f/s
# 20234: done 470 games, lr 0.00153 reward 1.655, eps 1.53, speed 353.81 f/s
# 20275: done 471 games, lr 0.00153 reward 1.648, eps 1.53, speed 350.03 f/s
# 20297: done 472 games, lr 0.00153 reward 1.636, eps 1.53, speed 290.93 f/s
# 20331: done 473 games, lr 0.00153 reward 1.635, eps 1.53, speed 342.70 f/s
# 20377: done 474 games, lr 0.00153 reward 1.640, eps 1.53, speed 370.59 f/s
# 20415: done 475 games, lr 0.00153 reward 1.645, eps 1.53, speed 347.58 f/s
# 20472: done 476 games, lr 0.00153 reward 1.646, eps 1.53, speed 384.16 f/s
# 20514: done 477 games, lr 0.00153 reward 1.639, eps 1.53, speed 374.09 f/s
# 20549: done 478 games, lr 0.00153 reward 1.634, eps 1.53, speed 339.93 f/s
# 20594: done 479 games, lr 0.00153 reward 1.631, eps 1.53, speed 374.46 f/s
# 20611: done 480 games, lr 0.00153 reward 1.622, eps 1.53, speed 226.21 f/s
# 20633: done 481 games, lr 0.00153 reward 1.612, eps 1.53, speed 275.98 f/s
# 20713: done 482 games, lr 0.00153 reward 1.624, eps 1.53, speed 422.25 f/s
# 20755: done 483 games, lr 0.00153 reward 1.630, eps 1.53, speed 360.09 f/s
# 20817: done 484 games, lr 0.00153 reward 1.633, eps 1.53, speed 385.43 f/s
# 20866: done 485 games, lr 0.00153 reward 1.636, eps 1.53, speed 355.21 f/s
# 20896: done 486 games, lr 0.00153 reward 1.621, eps 1.53, speed 314.53 f/s
# 20935: done 487 games, lr 0.00153 reward 1.618, eps 1.53, speed 351.92 f/s
# 20981: done 488 games, lr 0.00153 reward 1.621, eps 1.53, speed 381.48 f/s
# 21028: done 489 games, lr 0.00153 reward 1.624, eps 1.53, speed 368.22 f/s
# 21061: done 490 games, lr 0.00153 reward 1.614, eps 1.53, speed 326.26 f/s
# 21099: done 491 games, lr 0.00153 reward 1.621, eps 1.53, speed 327.23 f/s
# 21137: done 492 games, lr 0.00153 reward 1.616, eps 1.53, speed 331.68 f/s
# 21189: done 493 games, lr 0.00153 reward 1.626, eps 1.53, speed 364.95 f/s
# 21236: done 494 games, lr 0.00153 reward 1.627, eps 1.53, speed 355.82 f/s
# 21271: done 495 games, lr 0.00152 reward 1.623, eps 1.52, speed 325.61 f/s
# 21320: done 496 games, lr 0.00152 reward 1.631, eps 1.52, speed 362.09 f/s
# 21391: done 497 games, lr 0.00152 reward 1.648, eps 1.52, speed 397.02 f/s
# 21434: done 498 games, lr 0.00152 reward 1.650, eps 1.52, speed 344.88 f/s
# 21470: done 499 games, lr 0.00152 reward 1.646, eps 1.52, speed 336.39 f/s
# 21521: done 500 games, lr 0.00152 reward 1.646, eps 1.52, speed 368.70 f/s
# 21550: done 501 games, lr 0.00152 reward 1.639, eps 1.52, speed 301.18 f/s
# 21595: done 502 games, lr 0.00152 reward 1.642, eps 1.52, speed 347.05 f/s
# 21634: done 503 games, lr 0.00152 reward 1.639, eps 1.52, speed 347.26 f/s
# 21663: done 504 games, lr 0.00152 reward 1.637, eps 1.52, speed 306.62 f/s
# 21696: done 505 games, lr 0.00152 reward 1.632, eps 1.52, speed 324.29 f/s
# 21746: done 506 games, lr 0.00152 reward 1.629, eps 1.52, speed 381.64 f/s
# 21782: done 507 games, lr 0.00152 reward 1.622, eps 1.52, speed 344.17 f/s
# 21811: done 508 games, lr 0.00152 reward 1.624, eps 1.52, speed 306.31 f/s
# 21844: done 509 games, lr 0.00152 reward 1.622, eps 1.52, speed 319.59 f/s
# 21883: done 510 games, lr 0.00152 reward 1.626, eps 1.52, speed 349.93 f/s
# 21925: done 511 games, lr 0.00152 reward 1.624, eps 1.52, speed 366.70 f/s
# 21958: done 512 games, lr 0.00152 reward 1.617, eps 1.52, speed 337.91 f/s
# 22013: done 513 games, lr 0.00152 reward 1.620, eps 1.52, speed 389.20 f/s
# 22043: done 514 games, lr 0.00152 reward 1.607, eps 1.52, speed 314.32 f/s
# 22089: done 515 games, lr 0.00152 reward 1.617, eps 1.52, speed 376.92 f/s
# 22131: done 516 games, lr 0.00152 reward 1.618, eps 1.52, speed 367.23 f/s
# 22225: done 517 games, lr 0.00152 reward 1.633, eps 1.52, speed 432.67 f/s
# 22263: done 518 games, lr 0.00152 reward 1.629, eps 1.52, speed 347.51 f/s
# 22295: done 519 games, lr 0.00152 reward 1.627, eps 1.52, speed 333.05 f/s
# 22392: done 520 games, lr 0.00152 reward 1.639, eps 1.52, speed 441.66 f/s
# 22426: done 521 games, lr 0.00152 reward 1.637, eps 1.52, speed 340.89 f/s
# 22466: done 522 games, lr 0.00152 reward 1.637, eps 1.52, speed 350.34 f/s
# 22491: done 523 games, lr 0.00152 reward 1.625, eps 1.52, speed 297.42 f/s
# 22532: done 524 games, lr 0.00152 reward 1.574, eps 1.52, speed 351.98 f/s
# 22567: done 525 games, lr 0.00152 reward 1.574, eps 1.52, speed 342.20 f/s
# 22610: done 526 games, lr 0.00152 reward 1.552, eps 1.52, speed 367.59 f/s
# 22659: done 527 games, lr 0.00152 reward 1.556, eps 1.52, speed 380.06 f/s
# 22714: done 528 games, lr 0.00152 reward 1.562, eps 1.52, speed 382.27 f/s
# 22760: done 529 games, lr 0.00151 reward 1.562, eps 1.51, speed 369.67 f/s
# 22807: done 530 games, lr 0.00151 reward 1.570, eps 1.51, speed 385.79 f/s
# 22855: done 531 games, lr 0.00151 reward 1.576, eps 1.51, speed 375.92 f/s
# 22958: done 532 games, lr 0.00151 reward 1.622, eps 1.51, speed 426.72 f/s
# 23004: done 533 games, lr 0.00151 reward 1.626, eps 1.51, speed 363.66 f/s
# 23042: done 534 games, lr 0.00151 reward 1.618, eps 1.51, speed 348.95 f/s
# 23069: done 535 games, lr 0.00151 reward 1.605, eps 1.51, speed 311.41 f/s
# 23110: done 536 games, lr 0.00151 reward 1.614, eps 1.51, speed 352.35 f/s
# 23146: done 537 games, lr 0.00151 reward 1.616, eps 1.51, speed 333.63 f/s
# 23177: done 538 games, lr 0.00151 reward 1.614, eps 1.51, speed 334.94 f/s
# 23212: done 539 games, lr 0.00151 reward 1.610, eps 1.51, speed 337.21 f/s
# 23246: done 540 games, lr 0.00151 reward 1.616, eps 1.51, speed 336.24 f/s
# 23291: done 541 games, lr 0.00151 reward 1.622, eps 1.51, speed 362.32 f/s
# 23330: done 542 games, lr 0.00151 reward 1.625, eps 1.51, speed 343.55 f/s
# 23381: done 543 games, lr 0.00151 reward 1.636, eps 1.51, speed 386.42 f/s
# 23419: done 544 games, lr 0.00151 reward 1.627, eps 1.51, speed 359.53 f/s
# 23472: done 545 games, lr 0.00151 reward 1.549, eps 1.51, speed 388.01 f/s
# 23505: done 546 games, lr 0.00151 reward 1.550, eps 1.51, speed 324.53 f/s
# 23553: done 547 games, lr 0.00151 reward 1.540, eps 1.51, speed 369.80 f/s
# 23583: done 548 games, lr 0.00151 reward 1.537, eps 1.51, speed 330.62 f/s
# 23698: done 549 games, lr 0.00151 reward 1.585, eps 1.51, speed 444.50 f/s
# 23724: done 550 games, lr 0.00151 reward 1.574, eps 1.51, speed 285.43 f/s
# 23751: done 551 games, lr 0.00151 reward 1.575, eps 1.51, speed 297.64 f/s
# 23791: done 552 games, lr 0.00151 reward 1.573, eps 1.51, speed 354.36 f/s
# 23821: done 553 games, lr 0.00151 reward 1.568, eps 1.51, speed 327.41 f/s
# 23855: done 554 games, lr 0.00151 reward 1.572, eps 1.51, speed 339.88 f/s
# 23975: done 555 games, lr 0.00151 reward 1.591, eps 1.51, speed 442.68 f/s
# 24014: done 556 games, lr 0.00151 reward 1.598, eps 1.51, speed 352.51 f/s
# 24062: done 557 games, lr 0.00151 reward 1.604, eps 1.51, speed 378.94 f/s
# 24104: done 558 games, lr 0.00151 reward 1.605, eps 1.51, speed 367.38 f/s
# 24146: done 559 games, lr 0.00151 reward 1.613, eps 1.51, speed 355.13 f/s
# 24181: done 560 games, lr 0.00151 reward 1.614, eps 1.51, speed 332.92 f/s
# 24212: done 561 games, lr 0.00151 reward 1.618, eps 1.51, speed 328.66 f/s
# 24251: done 562 games, lr 0.00150 reward 1.615, eps 1.50, speed 359.40 f/s
# 24430: done 563 games, lr 0.00150 reward 1.678, eps 1.50, speed 462.47 f/s
# 24464: done 564 games, lr 0.00150 reward 1.676, eps 1.50, speed 343.86 f/s
# 24497: done 565 games, lr 0.00150 reward 1.671, eps 1.50, speed 329.82 f/s
# 24576: done 566 games, lr 0.00150 reward 1.693, eps 1.50, speed 423.03 f/s
# 24620: done 567 games, lr 0.00150 reward 1.672, eps 1.50, speed 316.65 f/s
# 24664: done 568 games, lr 0.00150 reward 1.672, eps 1.50, speed 361.15 f/s
# 24692: done 569 games, lr 0.00150 reward 1.670, eps 1.50, speed 315.91 f/s
# 24746: done 570 games, lr 0.00150 reward 1.669, eps 1.50, speed 384.77 f/s
# 24775: done 571 games, lr 0.00150 reward 1.670, eps 1.50, speed 314.31 f/s
# 24798: done 572 games, lr 0.00150 reward 1.673, eps 1.50, speed 280.62 f/s
# 24924: done 573 games, lr 0.00150 reward 1.738, eps 1.50, speed 447.90 f/s
# 24985: done 574 games, lr 0.00150 reward 1.743, eps 1.50, speed 395.58 f/s
# 25054: done 575 games, lr 0.00150 reward 1.752, eps 1.50, speed 401.75 f/s
# 25076: done 576 games, lr 0.00150 reward 1.737, eps 1.50, speed 280.70 f/s
# 25108: done 577 games, lr 0.00150 reward 1.741, eps 1.50, speed 324.06 f/s
# 25166: done 578 games, lr 0.00150 reward 1.753, eps 1.50, speed 394.24 f/s
# 25315: done 579 games, lr 0.00150 reward 1.809, eps 1.50, speed 450.20 f/s
# 25350: done 580 games, lr 0.00150 reward 1.814, eps 1.50, speed 339.07 f/s
# 25386: done 581 games, lr 0.00150 reward 1.819, eps 1.50, speed 344.74 f/s
# 25415: done 582 games, lr 0.00150 reward 1.806, eps 1.50, speed 309.08 f/s
# 25522: done 583 games, lr 0.00150 reward 1.842, eps 1.50, speed 438.18 f/s
# 25559: done 584 games, lr 0.00150 reward 1.828, eps 1.50, speed 340.57 f/s
# 25598: done 585 games, lr 0.00150 reward 1.820, eps 1.50, speed 358.91 f/s
# 25661: done 586 games, lr 0.00150 reward 1.835, eps 1.50, speed 403.97 f/s
# 25699: done 587 games, lr 0.00150 reward 1.839, eps 1.50, speed 337.18 f/s
# 25744: done 588 games, lr 0.00150 reward 1.838, eps 1.50, speed 366.62 f/s
# 25786: done 589 games, lr 0.00149 reward 1.841, eps 1.49, speed 345.69 f/s
# 25823: done 590 games, lr 0.00149 reward 1.843, eps 1.49, speed 341.55 f/s
# 25877: done 591 games, lr 0.00149 reward 1.830, eps 1.49, speed 376.89 f/s
# 25917: done 592 games, lr 0.00149 reward 1.835, eps 1.49, speed 355.12 f/s
# 25965: done 593 games, lr 0.00149 reward 1.827, eps 1.49, speed 365.29 f/s
# 26013: done 594 games, lr 0.00149 reward 1.830, eps 1.49, speed 362.80 f/s
# 26052: done 595 games, lr 0.00149 reward 1.833, eps 1.49, speed 353.61 f/s
# 26094: done 596 games, lr 0.00149 reward 1.825, eps 1.49, speed 354.70 f/s
# 26142: done 597 games, lr 0.00149 reward 1.813, eps 1.49, speed 367.63 f/s
# 26163: done 598 games, lr 0.00149 reward 1.808, eps 1.49, speed 278.06 f/s
# 26208: done 599 games, lr 0.00149 reward 1.813, eps 1.49, speed 365.88 f/s
# 26224: done 600 games, lr 0.00149 reward 1.802, eps 1.49, speed 238.51 f/s
# 26264: done 601 games, lr 0.00149 reward 1.801, eps 1.49, speed 350.92 f/s
# 26289: done 602 games, lr 0.00149 reward 1.796, eps 1.49, speed 286.67 f/s
# 26331: done 603 games, lr 0.00149 reward 1.794, eps 1.49, speed 352.98 f/s
# 26382: done 604 games, lr 0.00149 reward 1.800, eps 1.49, speed 380.31 f/s
# 26440: done 605 games, lr 0.00149 reward 1.819, eps 1.49, speed 394.82 f/s
# 26497: done 606 games, lr 0.00149 reward 1.827, eps 1.49, speed 386.47 f/s
# 26554: done 607 games, lr 0.00149 reward 1.839, eps 1.49, speed 385.84 f/s
# 26678: done 608 games, lr 0.00149 reward 1.868, eps 1.49, speed 448.05 f/s
# 26726: done 609 games, lr 0.00149 reward 1.881, eps 1.49, speed 370.32 f/s
# 26780: done 610 games, lr 0.00149 reward 1.883, eps 1.49, speed 379.05 f/s
# 26824: done 611 games, lr 0.00149 reward 1.891, eps 1.49, speed 376.53 f/s
# 26861: done 612 games, lr 0.00149 reward 1.890, eps 1.49, speed 350.94 f/s
# 26885: done 613 games, lr 0.00149 reward 1.879, eps 1.49, speed 292.60 f/s
# 26926: done 614 games, lr 0.00149 reward 1.887, eps 1.49, speed 351.74 f/s
# 26978: done 615 games, lr 0.00149 reward 1.879, eps 1.49, speed 372.34 f/s
# 27023: done 616 games, lr 0.00149 reward 1.875, eps 1.49, speed 367.20 f/s
# 27111: done 617 games, lr 0.00149 reward 1.896, eps 1.49, speed 432.59 f/s
# 27225: done 618 games, lr 0.00149 reward 1.915, eps 1.49, speed 441.36 f/s
# 27262: done 619 games, lr 0.00148 reward 1.923, eps 1.48, speed 344.42 f/s
# 27301: done 620 games, lr 0.00148 reward 1.907, eps 1.48, speed 349.06 f/s
# 27342: done 621 games, lr 0.00148 reward 1.905, eps 1.48, speed 365.87 f/s
# 27398: done 622 games, lr 0.00148 reward 1.907, eps 1.48, speed 382.22 f/s
# 27423: done 623 games, lr 0.00148 reward 1.907, eps 1.48, speed 292.82 f/s
# 27558: done 624 games, lr 0.00148 reward 2.022, eps 1.48, speed 460.71 f/s
# 27607: done 625 games, lr 0.00148 reward 2.026, eps 1.48, speed 376.67 f/s
# 27650: done 626 games, lr 0.00148 reward 2.033, eps 1.48, speed 359.14 f/s
# 27701: done 627 games, lr 0.00148 reward 2.030, eps 1.48, speed 380.57 f/s
# 27735: done 628 games, lr 0.00148 reward 2.025, eps 1.48, speed 339.75 f/s
# 27757: done 629 games, lr 0.00148 reward 2.022, eps 1.48, speed 277.50 f/s
# 27801: done 630 games, lr 0.00148 reward 2.018, eps 1.48, speed 354.50 f/s
# 27835: done 631 games, lr 0.00148 reward 2.013, eps 1.48, speed 324.75 f/s
# 27882: done 632 games, lr 0.00148 reward 1.972, eps 1.48, speed 372.52 f/s
# 27922: done 633 games, lr 0.00148 reward 1.962, eps 1.48, speed 355.67 f/s
# 27965: done 634 games, lr 0.00148 reward 1.970, eps 1.48, speed 372.86 f/s
# 27986: done 635 games, lr 0.00148 reward 1.969, eps 1.48, speed 271.20 f/s
# 28006: done 636 games, lr 0.00148 reward 1.957, eps 1.48, speed 269.39 f/s
# 28057: done 637 games, lr 0.00148 reward 1.965, eps 1.48, speed 376.97 f/s
# 28102: done 638 games, lr 0.00148 reward 1.969, eps 1.48, speed 369.26 f/s
# 28151: done 639 games, lr 0.00148 reward 1.982, eps 1.48, speed 377.78 f/s
# 28188: done 640 games, lr 0.00148 reward 1.978, eps 1.48, speed 338.70 f/s
# 28230: done 641 games, lr 0.00148 reward 1.979, eps 1.48, speed 353.58 f/s
# 28269: done 642 games, lr 0.00148 reward 1.979, eps 1.48, speed 354.33 f/s
# 28329: done 643 games, lr 0.00148 reward 1.984, eps 1.48, speed 401.35 f/s
# 28364: done 644 games, lr 0.00148 reward 1.986, eps 1.48, speed 332.99 f/s
# ...
# 90868: done 2030 games, lr 0.00106 reward 1.651, eps 1.06, speed 433.79 f/s
# 90914: done 2031 games, lr 0.00106 reward 1.664, eps 1.06, speed 371.50 f/s
# 90958: done 2032 games, lr 0.00106 reward 1.665, eps 1.06, speed 370.40 f/s
# 91000: done 2033 games, lr 0.00106 reward 1.667, eps 1.06, speed 360.52 f/s
# 91049: done 2034 games, lr 0.00106 reward 1.669, eps 1.06, speed 377.32 f/s
# 91093: done 2035 games, lr 0.00106 reward 1.670, eps 1.06, speed 357.30 f/s
# 91135: done 2036 games, lr 0.00106 reward 1.673, eps 1.06, speed 355.95 f/s
# 91174: done 2037 games, lr 0.00106 reward 1.685, eps 1.06, speed 342.94 f/s
# 91212: done 2038 games, lr 0.00106 reward 1.673, eps 1.06, speed 348.32 f/s
# 91255: done 2039 games, lr 0.00106 reward 1.671, eps 1.06, speed 358.10 f/s
# 91301: done 2040 games, lr 0.00106 reward 1.673, eps 1.06, speed 355.52 f/s
# 91342: done 2041 games, lr 0.00106 reward 1.665, eps 1.06, speed 346.22 f/s
# 91382: done 2042 games, lr 0.00106 reward 1.661, eps 1.06, speed 360.84 f/s
# 91427: done 2043 games, lr 0.00106 reward 1.669, eps 1.06, speed 357.24 f/s
# 91554: done 2044 games, lr 0.00106 reward 1.691, eps 1.06, speed 441.52 f/s
# 91589: done 2045 games, lr 0.00106 reward 1.697, eps 1.06, speed 342.94 f/s
# 91637: done 2046 games, lr 0.00106 reward 1.681, eps 1.06, speed 336.74 f/s
# 91682: done 2047 games, lr 0.00106 reward 1.690, eps 1.06, speed 346.49 f/s
# 91719: done 2048 games, lr 0.00106 reward 1.694, eps 1.06, speed 322.82 f/s
# 91760: done 2049 games, lr 0.00105 reward 1.683, eps 1.05, speed 359.59 f/s
# 91795: done 2050 games, lr 0.00105 reward 1.684, eps 1.05, speed 333.33 f/s
# 91810: done 2051 games, lr 0.00105 reward 1.678, eps 1.05, speed 233.25 f/s
# 91846: done 2052 games, lr 0.00105 reward 1.671, eps 1.05, speed 335.79 f/s
# 91888: done 2053 games, lr 0.00105 reward 1.673, eps 1.05, speed 355.33 f/s
# 91930: done 2054 games, lr 0.00105 reward 1.676, eps 1.05, speed 348.87 f/s
# 91978: done 2055 games, lr 0.00105 reward 1.686, eps 1.05, speed 344.09 f/s
# 92070: done 2056 games, lr 0.00105 reward 1.718, eps 1.05, speed 407.70 f/s
# 92107: done 2057 games, lr 0.00105 reward 1.705, eps 1.05, speed 329.14 f/s
# 92151: done 2058 games, lr 0.00105 reward 1.711, eps 1.05, speed 342.52 f/s
# 92209: done 2059 games, lr 0.00105 reward 1.720, eps 1.05, speed 368.70 f/s
# 92227: done 2060 games, lr 0.00105 reward 1.712, eps 1.05, speed 239.77 f/s
# 92331: done 2061 games, lr 0.00105 reward 1.792, eps 1.05, speed 431.43 f/s
# 92378: done 2062 games, lr 0.00105 reward 1.789, eps 1.05, speed 367.80 f/s
# 92429: done 2063 games, lr 0.00105 reward 1.765, eps 1.05, speed 341.11 f/s
# 92484: done 2064 games, lr 0.00105 reward 1.780, eps 1.05, speed 393.40 f/s
# 92580: done 2065 games, lr 0.00105 reward 1.803, eps 1.05, speed 431.63 f/s
# 92625: done 2066 games, lr 0.00105 reward 1.794, eps 1.05, speed 363.89 f/s
# 92678: done 2067 games, lr 0.00105 reward 1.799, eps 1.05, speed 381.53 f/s
# 92713: done 2068 games, lr 0.00105 reward 1.781, eps 1.05, speed 332.55 f/s
# 92756: done 2069 games, lr 0.00105 reward 1.774, eps 1.05, speed 304.44 f/s
# 92795: done 2070 games, lr 0.00105 reward 1.767, eps 1.05, speed 348.82 f/s
# 92831: done 2071 games, lr 0.00105 reward 1.767, eps 1.05, speed 343.40 f/s
# 92900: done 2072 games, lr 0.00105 reward 1.776, eps 1.05, speed 406.55 f/s
# 92923: done 2073 games, lr 0.00105 reward 1.770, eps 1.05, speed 275.31 f/s
# 92957: done 2074 games, lr 0.00105 reward 1.763, eps 1.05, speed 328.84 f/s
# 92995: done 2075 games, lr 0.00105 reward 1.768, eps 1.05, speed 337.73 f/s
# 93044: done 2076 games, lr 0.00105 reward 1.772, eps 1.05, speed 380.22 f/s
# 93086: done 2077 games, lr 0.00105 reward 1.767, eps 1.05, speed 366.34 f/s
# 93120: done 2078 games, lr 0.00105 reward 1.769, eps 1.05, speed 322.21 f/s
# 93152: done 2079 games, lr 0.00105 reward 1.763, eps 1.05, speed 267.39 f/s
# 93191: done 2080 games, lr 0.00105 reward 1.769, eps 1.05, speed 334.79 f/s
# 93231: done 2081 games, lr 0.00105 reward 1.779, eps 1.05, speed 356.14 f/s
# 93302: done 2082 games, lr 0.00104 reward 1.794, eps 1.04, speed 382.24 f/s
# 93347: done 2083 games, lr 0.00104 reward 1.805, eps 1.04, speed 363.91 f/s
# 93389: done 2084 games, lr 0.00104 reward 1.810, eps 1.04, speed 350.60 f/s
# 93430: done 2085 games, lr 0.00104 reward 1.759, eps 1.04, speed 361.18 f/s
# 93456: done 2086 games, lr 0.00104 reward 1.764, eps 1.04, speed 310.46 f/s
# 93509: done 2087 games, lr 0.00104 reward 1.765, eps 1.04, speed 380.12 f/s
# 93528: done 2088 games, lr 0.00104 reward 1.711, eps 1.04, speed 260.10 f/s
# 93561: done 2089 games, lr 0.00104 reward 1.698, eps 1.04, speed 331.13 f/s
# 93592: done 2090 games, lr 0.00104 reward 1.697, eps 1.04, speed 329.64 f/s
# 93609: done 2091 games, lr 0.00104 reward 1.690, eps 1.04, speed 253.20 f/s
# 93641: done 2092 games, lr 0.00104 reward 1.684, eps 1.04, speed 263.03 f/s
# 93658: done 2093 games, lr 0.00104 reward 1.674, eps 1.04, speed 187.11 f/s
# 93692: done 2094 games, lr 0.00104 reward 1.672, eps 1.04, speed 296.68 f/s
# 93723: done 2095 games, lr 0.00104 reward 1.673, eps 1.04, speed 258.08 f/s
# 93755: done 2096 games, lr 0.00104 reward 1.679, eps 1.04, speed 320.73 f/s
# 93807: done 2097 games, lr 0.00104 reward 1.685, eps 1.04, speed 352.36 f/s
# 93830: done 2098 games, lr 0.00104 reward 1.678, eps 1.04, speed 280.42 f/s
# 93859: done 2099 games, lr 0.00104 reward 1.677, eps 1.04, speed 256.59 f/s
# 93945: done 2100 games, lr 0.00104 reward 1.706, eps 1.04, speed 411.20 f/s
# 93975: done 2101 games, lr 0.00104 reward 1.714, eps 1.04, speed 315.52 f/s
# 94075: done 2102 games, lr 0.00104 reward 1.758, eps 1.04, speed 424.68 f/s
# 94114: done 2103 games, lr 0.00104 reward 1.760, eps 1.04, speed 336.55 f/s
# 94156: done 2104 games, lr 0.00104 reward 1.765, eps 1.04, speed 347.29 f/s
# 94206: done 2105 games, lr 0.00104 reward 1.757, eps 1.04, speed 378.08 f/s
# 94250: done 2106 games, lr 0.00104 reward 1.756, eps 1.04, speed 361.34 f/s
# 94286: done 2107 games, lr 0.00104 reward 1.749, eps 1.04, speed 331.64 f/s
# 94367: done 2108 games, lr 0.00104 reward 1.761, eps 1.04, speed 422.16 f/s
# 94413: done 2109 games, lr 0.00104 reward 1.763, eps 1.04, speed 380.37 f/s
# 94437: done 2110 games, lr 0.00104 reward 1.758, eps 1.04, speed 254.91 f/s
# 94472: done 2111 games, lr 0.00104 reward 1.762, eps 1.04, speed 335.51 f/s
# 94519: done 2112 games, lr 0.00104 reward 1.759, eps 1.04, speed 368.33 f/s
# 94576: done 2113 games, lr 0.00104 reward 1.765, eps 1.04, speed 391.79 f/s
# 94614: done 2114 games, lr 0.00104 reward 1.754, eps 1.04, speed 351.89 f/s
# 94655: done 2115 games, lr 0.00104 reward 1.742, eps 1.04, speed 357.31 f/s
# 94693: done 2116 games, lr 0.00104 reward 1.746, eps 1.04, speed 349.18 f/s
# 94738: done 2117 games, lr 0.00104 reward 1.754, eps 1.04, speed 365.73 f/s
# 94775: done 2118 games, lr 0.00103 reward 1.757, eps 1.03, speed 347.06 f/s
# 94813: done 2119 games, lr 0.00103 reward 1.761, eps 1.03, speed 353.85 f/s
# 94850: done 2120 games, lr 0.00103 reward 1.764, eps 1.03, speed 348.03 f/s
# 94885: done 2121 games, lr 0.00103 reward 1.772, eps 1.03, speed 335.50 f/s
# 94924: done 2122 games, lr 0.00103 reward 1.778, eps 1.03, speed 348.54 f/s
# 94975: done 2123 games, lr 0.00103 reward 1.776, eps 1.03, speed 329.70 f/s
# 95003: done 2124 games, lr 0.00103 reward 1.776, eps 1.03, speed 313.48 f/s
# 95056: done 2125 games, lr 0.00103 reward 1.763, eps 1.03, speed 385.93 f/s
# 95105: done 2126 games, lr 0.00103 reward 1.773, eps 1.03, speed 368.83 f/s
# 95145: done 2127 games, lr 0.00103 reward 1.777, eps 1.03, speed 353.86 f/s
# 95206: done 2128 games, lr 0.00103 reward 1.785, eps 1.03, speed 404.50 f/s
# 95245: done 2129 games, lr 0.00103 reward 1.785, eps 1.03, speed 348.47 f/s
# 95290: done 2130 games, lr 0.00103 reward 1.727, eps 1.03, speed 364.71 f/s
# 95322: done 2131 games, lr 0.00103 reward 1.721, eps 1.03, speed 323.63 f/s
# 95356: done 2132 games, lr 0.00103 reward 1.721, eps 1.03, speed 332.48 f/s
# 95393: done 2133 games, lr 0.00103 reward 1.717, eps 1.03, speed 332.80 f/s
# 95425: done 2134 games, lr 0.00103 reward 1.712, eps 1.03, speed 319.94 f/s
# 95515: done 2135 games, lr 0.00103 reward 1.747, eps 1.03, speed 416.26 f/s
# 95611: done 2136 games, lr 0.00103 reward 1.782, eps 1.03, speed 431.49 f/s
# 95702: done 2137 games, lr 0.00103 reward 1.788, eps 1.03, speed 428.40 f/s
# 95734: done 2138 games, lr 0.00103 reward 1.793, eps 1.03, speed 318.70 f/s
# 95785: done 2139 games, lr 0.00103 reward 1.795, eps 1.03, speed 376.32 f/s
# 95836: done 2140 games, lr 0.00103 reward 1.790, eps 1.03, speed 387.37 f/s
# 95869: done 2141 games, lr 0.00103 reward 1.787, eps 1.03, speed 332.17 f/s
# 95910: done 2142 games, lr 0.00103 reward 1.792, eps 1.03, speed 362.05 f/s
# 95932: done 2143 games, lr 0.00103 reward 1.789, eps 1.03, speed 276.14 f/s
# 95960: done 2144 games, lr 0.00103 reward 1.764, eps 1.03, speed 285.90 f/s
# 96020: done 2145 games, lr 0.00103 reward 1.766, eps 1.03, speed 384.22 f/s
# 96060: done 2146 games, lr 0.00103 reward 1.769, eps 1.03, speed 365.54 f/s
# 96104: done 2147 games, lr 0.00103 reward 1.766, eps 1.03, speed 351.98 f/s
# 96214: done 2148 games, lr 0.00103 reward 1.799, eps 1.03, speed 435.50 f/s
# 96298: done 2149 games, lr 0.00102 reward 1.819, eps 1.02, speed 431.82 f/s
# 96329: done 2150 games, lr 0.00102 reward 1.810, eps 1.02, speed 334.41 f/s
# 96346: done 2151 games, lr 0.00102 reward 1.811, eps 1.02, speed 248.25 f/s
# 96385: done 2152 games, lr 0.00102 reward 1.812, eps 1.02, speed 334.84 f/s
# 96425: done 2153 games, lr 0.00102 reward 1.805, eps 1.02, speed 363.13 f/s
# 96507: done 2154 games, lr 0.00102 reward 1.831, eps 1.02, speed 426.49 f/s
# 96610: done 2155 games, lr 0.00102 reward 1.891, eps 1.02, speed 436.46 f/s
# 96646: done 2156 games, lr 0.00102 reward 1.853, eps 1.02, speed 333.40 f/s
# 96686: done 2157 games, lr 0.00102 reward 1.859, eps 1.02, speed 336.09 f/s
# 96701: done 2158 games, lr 0.00102 reward 1.845, eps 1.02, speed 228.67 f/s
# 96743: done 2159 games, lr 0.00102 reward 1.833, eps 1.02, speed 357.28 f/s
# 96876: done 2160 games, lr 0.00102 reward 1.875, eps 1.02, speed 451.83 f/s
# 96932: done 2161 games, lr 0.00102 reward 1.799, eps 1.02, speed 403.79 f/s
# 96964: done 2162 games, lr 0.00102 reward 1.797, eps 1.02, speed 322.07 f/s
# 97014: done 2163 games, lr 0.00102 reward 1.798, eps 1.02, speed 380.33 f/s
# 97057: done 2164 games, lr 0.00102 reward 1.793, eps 1.02, speed 337.38 f/s
# 97104: done 2165 games, lr 0.00102 reward 1.781, eps 1.02, speed 376.08 f/s
# 97154: done 2166 games, lr 0.00102 reward 1.787, eps 1.02, speed 377.20 f/s
# 97201: done 2167 games, lr 0.00102 reward 1.787, eps 1.02, speed 375.63 f/s
# 97244: done 2168 games, lr 0.00102 reward 1.785, eps 1.02, speed 356.76 f/s
# 97283: done 2169 games, lr 0.00102 reward 1.786, eps 1.02, speed 346.73 f/s
# 97330: done 2170 games, lr 0.00102 reward 1.792, eps 1.02, speed 374.30 f/s
# 97360: done 2171 games, lr 0.00102 reward 1.791, eps 1.02, speed 318.33 f/s
# 97396: done 2172 games, lr 0.00102 reward 1.776, eps 1.02, speed 343.86 f/s
# 97436: done 2173 games, lr 0.00102 reward 1.775, eps 1.02, speed 347.88 f/s
# 97481: done 2174 games, lr 0.00102 reward 1.777, eps 1.02, speed 369.54 f/s
# 97523: done 2175 games, lr 0.00102 reward 1.786, eps 1.02, speed 361.51 f/s
# 97548: done 2176 games, lr 0.00102 reward 1.777, eps 1.02, speed 300.65 f/s
# 97590: done 2177 games, lr 0.00102 reward 1.779, eps 1.02, speed 367.68 f/s
# 97627: done 2178 games, lr 0.00102 reward 1.775, eps 1.02, speed 345.09 f/s
# 97668: done 2179 games, lr 0.00102 reward 1.776, eps 1.02, speed 341.22 f/s
# 97707: done 2180 games, lr 0.00102 reward 1.769, eps 1.02, speed 261.16 f/s
# 97802: done 2181 games, lr 0.00101 reward 1.815, eps 1.01, speed 413.65 f/s
# 97848: done 2182 games, lr 0.00101 reward 1.798, eps 1.01, speed 355.83 f/s
# 97890: done 2183 games, lr 0.00101 reward 1.794, eps 1.01, speed 357.79 f/s
# 97935: done 2184 games, lr 0.00101 reward 1.795, eps 1.01, speed 371.95 f/s
# 97970: done 2185 games, lr 0.00101 reward 1.798, eps 1.01, speed 288.07 f/s
# 98010: done 2186 games, lr 0.00101 reward 1.798, eps 1.01, speed 351.47 f/s
# 98026: done 2187 games, lr 0.00101 reward 1.783, eps 1.01, speed 239.72 f/s
# 98044: done 2188 games, lr 0.00101 reward 1.783, eps 1.01, speed 257.74 f/s
# 98065: done 2189 games, lr 0.00101 reward 1.781, eps 1.01, speed 282.69 f/s
# 98109: done 2190 games, lr 0.00101 reward 1.784, eps 1.01, speed 380.51 f/s
# 98131: done 2191 games, lr 0.00101 reward 1.782, eps 1.01, speed 287.66 f/s
# 98172: done 2192 games, lr 0.00101 reward 1.792, eps 1.01, speed 348.05 f/s
# 98215: done 2193 games, lr 0.00101 reward 1.799, eps 1.01, speed 350.34 f/s
# 98252: done 2194 games, lr 0.00101 reward 1.791, eps 1.01, speed 351.86 f/s
# 98280: done 2195 games, lr 0.00101 reward 1.786, eps 1.01, speed 323.78 f/s
# 98452: done 2196 games, lr 0.00101 reward 1.889, eps 1.01, speed 448.11 f/s
# 98487: done 2197 games, lr 0.00101 reward 1.886, eps 1.01, speed 328.92 f/s
# 98576: done 2198 games, lr 0.00101 reward 1.925, eps 1.01, speed 430.95 f/s
# 98622: done 2199 games, lr 0.00101 reward 1.931, eps 1.01, speed 370.31 f/s
# 98664: done 2200 games, lr 0.00101 reward 1.908, eps 1.01, speed 358.06 f/s
# 98725: done 2201 games, lr 0.00101 reward 1.911, eps 1.01, speed 379.12 f/s
# 98740: done 2202 games, lr 0.00101 reward 1.864, eps 1.01, speed 228.56 f/s
# 98808: done 2203 games, lr 0.00101 reward 1.878, eps 1.01, speed 401.70 f/s
# 98847: done 2204 games, lr 0.00101 reward 1.884, eps 1.01, speed 348.39 f/s
# 98889: done 2205 games, lr 0.00101 reward 1.878, eps 1.01, speed 352.49 f/s
# 98986: done 2206 games, lr 0.00101 reward 1.923, eps 1.01, speed 430.75 f/s
# 99034: done 2207 games, lr 0.00101 reward 1.929, eps 1.01, speed 372.16 f/s
# 99085: done 2208 games, lr 0.00101 reward 1.924, eps 1.01, speed 293.92 f/s
# 99139: done 2209 games, lr 0.00101 reward 1.925, eps 1.01, speed 377.38 f/s
# 99183: done 2210 games, lr 0.00101 reward 1.938, eps 1.01, speed 364.72 f/s
# 99235: done 2211 games, lr 0.00101 reward 1.936, eps 1.01, speed 384.99 f/s
# 99288: done 2212 games, lr 0.00100 reward 1.936, eps 1.00, speed 378.25 f/s
# 99342: done 2213 games, lr 0.00100 reward 1.935, eps 1.00, speed 367.28 f/s
# 99377: done 2214 games, lr 0.00100 reward 1.936, eps 1.00, speed 337.79 f/s
# 99417: done 2215 games, lr 0.00100 reward 1.939, eps 1.00, speed 358.19 f/s
# 99444: done 2216 games, lr 0.00100 reward 1.939, eps 1.00, speed 306.66 f/s
# 99484: done 2217 games, lr 0.00100 reward 1.937, eps 1.00, speed 346.78 f/s
# 99512: done 2218 games, lr 0.00100 reward 1.937, eps 1.00, speed 306.16 f/s
# 99653: done 2219 games, lr 0.00100 reward 1.984, eps 1.00, speed 453.23 f/s
# 99702: done 2220 games, lr 0.00100 reward 1.990, eps 1.00, speed 374.81 f/s
# 99716: done 2221 games, lr 0.00100 reward 1.976, eps 1.00, speed 217.02 f/s
# 99756: done 2222 games, lr 0.00100 reward 1.970, eps 1.00, speed 349.79 f/s
# 99797: done 2223 games, lr 0.00100 reward 1.972, eps 1.00, speed 350.91 f/s
# 99836: done 2224 games, lr 0.00100 reward 1.984, eps 1.00, speed 351.01 f/s
# 99878: done 2225 games, lr 0.00100 reward 1.969, eps 1.00, speed 352.55 f/s
# 99916: done 2226 games, lr 0.00100 reward 1.963, eps 1.00, speed 350.42 f/s
# 99960: done 2227 games, lr 0.00100 reward 1.962, eps 1.00, speed 357.73 f/s
# 99996: done 2228 games, lr 0.00100 reward 1.947, eps 1.00, speed 343.16 f/s
# 100032: done 2229 games, lr 0.00100 reward 1.947, eps 1.00, speed 7.15 f/s
# 100073: done 2230 games, lr 0.00100 reward 1.943, eps 1.00, speed 15.07 f/s
# 100111: done 2231 games, lr 0.00100 reward 1.940, eps 1.00, speed 15.34 f/s
# 100168: done 2232 games, lr 0.00100 reward 1.959, eps 1.00, speed 15.61 f/s
# 100208: done 2233 games, lr 0.00100 reward 1.972, eps 1.00, speed 15.58 f/s
# 100248: done 2234 games, lr 0.00100 reward 1.971, eps 1.00, speed 15.87 f/s
# 100290: done 2235 games, lr 0.00100 reward 1.936, eps 1.00, speed 15.98 f/s
# 100333: done 2236 games, lr 0.00100 reward 1.897, eps 1.00, speed 16.11 f/s
# 100373: done 2237 games, lr 0.00100 reward 1.888, eps 1.00, speed 16.13 f/s
# 100413: done 2238 games, lr 0.00100 reward 1.891, eps 1.00, speed 16.12 f/s
# 100460: done 2239 games, lr 0.00100 reward 1.892, eps 1.00, speed 16.19 f/s

# %% [markdown]
# ## model in action

# %%
MODEL_NAME = "MsPacman-v4-best_8.dat"

env = gym.make(env_name)
env = gym.wrappers.Monitor(env, env_name + "_record", force=True) # attach a monitor!
env = wrap_env(env)

net = DQN(env.observation_space.shape, env.action_space.n)
state = torch.load(MODEL_NAME, map_location = lambda stg, _:stg) # load dict from gpu to cpu!
net.load_state_dict(state)

state = env.reset()
total_reward = 0.0
c = collections.Counter()

while True:
    state_v = torch.tensor(np.array([state], copy=False))
    q_vals = net(state_v).data.numpy()[0] # need data to get it out!
    action = np.argmax(q_vals) # max idx
    c[action] += 1
    state, reward, done, _ = env.step(action)
    total_reward += reward
    if done:
        break
print("Total reward: %.2f" %total_reward)
print("Action counts:", c)

env.close() # stop recording
